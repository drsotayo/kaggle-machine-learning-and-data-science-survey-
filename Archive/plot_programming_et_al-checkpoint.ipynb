# %%
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd 
import seaborn as sns

# %%
df = pd.read_csv("kaggle_survey_2021_responses.csv", low_memory=False)

# %%
df.columns
# Out:
# Index(['Time from Start to Finish (seconds)', 'Q1', 'Q2', 'Q3', 'Q4', 'Q5',
#        'Q6', 'Q7_Part_1', 'Q7_Part_2', 'Q7_Part_3',
#        ...
#        'Q38_B_Part_3', 'Q38_B_Part_4', 'Q38_B_Part_5', 'Q38_B_Part_6',
#        'Q38_B_Part_7', 'Q38_B_Part_8', 'Q38_B_Part_9', 'Q38_B_Part_10',
#        'Q38_B_Part_11', 'Q38_B_OTHER'],
#       dtype='object', length=369)

# %%
df.head()
# Out:
#   Time from Start to Finish (seconds)                           Q1  \
# 0               Duration (in seconds)  What is your age (# years)?
# 1                                 910                        50-54
# 2                                 784                        50-54
# 3                                 924                        22-24
# 4                                 575                        45-49
#
#                                        Q2  \
# 0  What is your gender? - Selected Choice
# 1                                     Man
# 2                                     Man
# 3                                     Man
# 4                                     Man
#
#                                           Q3  \
# 0  In which country do you currently reside?
# 1                                      India
# 2                                  Indonesia
# 3                                   Pakistan
# 4                                     Mexico
#
# ...

# %%
data = df.drop([0])

# %%
data.columns[7:20]
# Out:
# Index(['Q7_Part_1', 'Q7_Part_2', 'Q7_Part_3', 'Q7_Part_4', 'Q7_Part_5',
#        'Q7_Part_6', 'Q7_Part_7', 'Q7_Part_8', 'Q7_Part_9', 'Q7_Part_10',
#        'Q7_Part_11', 'Q7_Part_12', 'Q7_OTHER'],
#       dtype='object')

# %%
list(data.columns[7:20])
# Out:
# ['Q7_Part_1',
#  'Q7_Part_2',
#  'Q7_Part_3',
#  'Q7_Part_4',
#  'Q7_Part_5',
#  'Q7_Part_6',
#  'Q7_Part_7',
#  'Q7_Part_8',
#  'Q7_Part_9',
#  'Q7_Part_10',
#  'Q7_Part_11',
#  'Q7_Part_12',
#  'Q7_OTHER']

# %%
data.loc[:,list(data.columns[7:20])]
# Out:
#       Q7_Part_1 Q7_Part_2 Q7_Part_3 Q7_Part_4 Q7_Part_5 Q7_Part_6   Q7_Part_7  \
# 1        Python         R       NaN       NaN       NaN       NaN         NaN
# 2           NaN       NaN       SQL         C       C++      Java         NaN
# 3        Python       NaN       NaN       NaN       C++      Java         NaN
# 4        Python       NaN       NaN       NaN       NaN       NaN         NaN
# 5        Python       NaN       NaN         C       NaN       NaN         NaN
# ...         ...       ...       ...       ...       ...       ...         ...
# 25969    Python       NaN       SQL       NaN       NaN       NaN  Javascript
# 25970    Python       NaN       NaN       NaN       NaN       NaN         NaN
# 25971       NaN       NaN       NaN       NaN       NaN       NaN         NaN
# 25972    Python       NaN       SQL       NaN       NaN       NaN         NaN
# 25973       NaN       NaN       NaN       NaN       NaN       NaN         NaN
#
# ...

# %%
data.loc[:,list(data.columns[7:20])].count()
# Out:
# Q7_Part_1     21860
# Q7_Part_2      5334
# Q7_Part_3     10756
# Q7_Part_4      4709
# Q7_Part_5      5535
# Q7_Part_6      4769
# Q7_Part_7      4332
# Q7_Part_8       305
# Q7_Part_9       242
# Q7_Part_10     2216
# Q7_Part_11     2935
# Q7_Part_12      319
# Q7_OTHER       2575
# dtype: int64

# %%
prog_lang = pd.DataFrame(data.loc[:,list(data.columns[7:20])].count(), columns=["count"])

# %%
prog_lang["Lang"] = ['Python', 'R', 'SQL', 'C', 'C++', 'Java', 
                'Javascript', 'Julia', 'Swift','Bash', 'MATLAB', 'None', 'Other']

# %%
prog_lang
# Out:
#             count        Lang
# Q7_Part_1   21860      Python
# Q7_Part_2    5334           R
# Q7_Part_3   10756         SQL
# Q7_Part_4    4709           C
# Q7_Part_5    5535         C++
# Q7_Part_6    4769        Java
# Q7_Part_7    4332  Javascript
# Q7_Part_8     305       Julia
# Q7_Part_9     242       Swift
# Q7_Part_10   2216        Bash
# Q7_Part_11   2935      MATLAB
# Q7_Part_12    319        None
# Q7_OTHER     2575       Other

# %%
prog_lang.sort_values(["count"], ascending=False, inplace=True)

# %%
prog_lang.reset_index()
# Out:
#          index  count        Lang
# 0    Q7_Part_1  21860      Python
# 1    Q7_Part_3  10756         SQL
# 2    Q7_Part_5   5535         C++
# 3    Q7_Part_2   5334           R
# 4    Q7_Part_6   4769        Java
# 5    Q7_Part_4   4709           C
# 6    Q7_Part_7   4332  Javascript
# 7   Q7_Part_11   2935      MATLAB
# 8     Q7_OTHER   2575       Other
# 9   Q7_Part_10   2216        Bash
# 10  Q7_Part_12    319        None
# 11   Q7_Part_8    305       Julia
# 12   Q7_Part_9    242       Swift

# %%
ax = sns.catplot(x = "count", y="Lang", data=prog_lang, kind="bar", aspect=4/2, color="green")

# %%
data.head()
# Out:
#   Time from Start to Finish (seconds)     Q1   Q2         Q3  \
# 1                                 910  50-54  Man      India
# 2                                 784  50-54  Man  Indonesia
# 3                                 924  22-24  Man   Pakistan
# 4                                 575  45-49  Man     Mexico
# 5                                 781  45-49  Man      India
#
#                   Q4                       Q5          Q6 Q7_Part_1 Q7_Part_2  \
# 1  Bachelor’s degree                    Other  5-10 years    Python         R
# 2    Master’s degree  Program/Project Manager   20+ years       NaN       NaN
# 3    Master’s degree        Software Engineer   1-3 years    Python       NaN
# 4    Doctoral degree       Research Scientist   20+ years    Python       NaN
# 5    Doctoral degree                    Other   < 1 years    Python       NaN
#
#   Q7_Part_3  ... Q38_B_Part_3 Q38_B_Part_4   Q38_B_Part_5 Q38_B_Part_6  \
# ...

# %%
Nigeria = data[data["Q3"] == "Nigeria"]

# %%
Nigeria
# Out:
#       Time from Start to Finish (seconds)     Q1   Q2       Q3  \
# 14                                    852  45-49  Man  Nigeria
# 15                                    838  22-24  Man  Nigeria
# 111                                   699  18-21  Man  Nigeria
# 166                                   904  25-29  Man  Nigeria
# 196                                   354  35-39  Man  Nigeria
# ...                                   ...    ...  ...      ...
# 25800                               14417  40-44  Man  Nigeria
# 25801                                 502  25-29  Man  Nigeria
# 25826                                 753  25-29  Man  Nigeria
# 25839                                 435  22-24  Man  Nigeria
# 25858                                 321  30-34  Man  Nigeria
#
#                                                       Q4  \
# 14                                       Master’s degree
# 15                                     Bachelor’s degree
# ...

# %%
prog_lang_ng = pd.DataFrame(Nigeria.loc[:,list(Nigeria.columns[7:20])].count(), columns=["count"])
prog_lang_ng ["Lang"] = ['Python', 'R', 'SQL', 'C', 'C++', 'Java', 
                'Javascript', 'Julia', 'Swift','Bash', 'MATLAB', 'None', 'Other']
prog_lang_ng.sort_values(["count"], ascending=False, inplace=True)

# %%
prog_lang_ng
# Out:
#             count        Lang
# Q7_Part_1     565      Python
# Q7_Part_3     227         SQL
# Q7_Part_7     113  Javascript
# Q7_Part_2     105           R
# Q7_Part_11     55      MATLAB
# Q7_Part_6      53        Java
# Q7_Part_5      52         C++
# Q7_OTHER       42       Other
# Q7_Part_4      30           C
# Q7_Part_12     14        None
# Q7_Part_10     10        Bash
# Q7_Part_9       3       Swift
# Q7_Part_8       1       Julia

# %%
ax = sns.catplot(x = "count", y="Lang", data=prog_lang_ng, kind="bar", aspect=4/2, color="green")

# %%
prog_lang
# Out:
#             count        Lang
# Q7_Part_1   21860      Python
# Q7_Part_3   10756         SQL
# Q7_Part_5    5535         C++
# Q7_Part_2    5334           R
# Q7_Part_6    4769        Java
# Q7_Part_4    4709           C
# Q7_Part_7    4332  Javascript
# Q7_Part_11   2935      MATLAB
# Q7_OTHER     2575       Other
# Q7_Part_10   2216        Bash
# Q7_Part_12    319        None
# Q7_Part_8     305       Julia
# Q7_Part_9     242       Swift

# %%
data["Q3"].unique()
# Out:
# array(['India', 'Indonesia', 'Pakistan', 'Mexico', 'Russia', 'Turkey',
#        'Australia', 'Nigeria', 'Greece', 'Belgium', 'Japan', 'Egypt',
#        'Singapore', 'Brazil', 'Poland', 'China',
#        'Iran, Islamic Republic of...', 'United States of America',
#        'Italy', 'Viet Nam', 'Israel', 'Peru', 'South Africa', 'Other',
#        'Spain', 'Bangladesh',
#        'United Kingdom of Great Britain and Northern Ireland', 'France',
#        'Switzerland', 'Algeria', 'Tunisia', 'Argentina', 'Sweden',
#        'Colombia', 'I do not wish to disclose my location', 'Canada',
#        'Chile', 'Netherlands', 'Ukraine', 'Saudi Arabia', 'Romania',
#        'Morocco', 'Austria', 'Taiwan', 'Kenya', 'Belarus', 'Ireland',
#        'Portugal', 'Hong Kong (S.A.R.)', 'Denmark', 'Germany',
#        'South Korea', 'Philippines', 'Sri Lanka', 'United Arab Emirates',
#        'Uganda', 'Ghana', 'Malaysia', 'Thailand', 'Nepal', 'Kazakhstan',
# ...

# %%
UK = data[data["Q3"] == "United Kingdom of Great Britain and Northern Ireland"]

# %%
prog_lang_uk = pd.DataFrame(UK.loc[:,list(UK.columns[7:20])].count(), columns=["count"])
prog_lang_uk ["Lang"] = ['Python', 'R', 'SQL', 'C', 'C++', 'Java', 
                'Javascript', 'Julia', 'Swift','Bash', 'MATLAB', 'None', 'Other']
prog_lang_uk.sort_values(["count"], ascending=False, inplace=True)

ax = sns.catplot(x = "count", y="Lang", data=prog_lang_uk, kind="bar", aspect=4/2, color="green")
plt.title('Programming languages used regualrly');

# %%
UK.shape
# Out:
# (550, 369)

# %%
pd.DataFrame(data['Q6'])
# Out:
#                               Q6
# 1                     5-10 years
# 2                      20+ years
# 3                      1-3 years
# 4                      20+ years
# 5                      < 1 years
# ...                          ...
# 25969                  1-3 years
# 25970                  1-3 years
# 25971  I have never written code
# 25972                 5-10 years
# 25973  I have never written code
#
# [25973 rows x 1 columns]

# %%
experience_years = pd.DataFrame(Nigeria['Q6']) 
experience_years = pd.DataFrame(experience_years.groupby(['Q6']).size())
experience_years.reset_index(inplace=True)
experience_years.columns = ['years','count']
experience_years.sort_values(['count'],ascending = False, inplace =True)

# %%
experience_years
# Out:
#                        years  count
# 0                  1-3 years    269
# 5                  < 1 years    241
# 3                  3-5 years     80
# 6  I have never written code     51
# 4                 5-10 years     46
# 1                10-20 years     13
# 2                  20+ years      2

# %%
ax = sns.catplot(x= 'years', y= 'count', data= experience_years,aspect = 4/2, color ='green', kind = 'bar')
plt.title('Years of writing and/or programming');

# %%
education_level = pd.DataFrame(Nigeria['Q4']) 
education_level = pd.DataFrame(education_level.groupby(['Q4']).size())
education_level.reset_index(inplace=True)
education_level.columns = ['education_level','count']
education_level.sort_values(['count'],ascending = False, inplace =True)

ax = sns.catplot(x= 'education_level', y= 'count', data= education_level,aspect = 4/2, color ='green', kind = 'bar')
plt.title('Highest level of education')
plt.xticks(rotation=90);

# %%
education_level
# Out:
#                                      education_level  count
# 0                                  Bachelor’s degree    363
# 3                                    Master’s degree    250
# 6  Some college/university study without earning ...     40
# 1                                    Doctoral degree     33
# 2                             I prefer not to answer      8
# 4               No formal education past high school      5
# 5                             Professional doctorate      3

# %%
IDE_usage = pd.DataFrame(Nigeria.loc[:,list(Nigeria.columns[21:34])].count(), columns=["count"])
IDE_usage ["IDE"] = ['Jupyter', 'Rstudio', 'Visual Studio', 'VScode', 
                     'PyCharm', 'Spyder', 'Notepad++', 'Sublime Text', 'Vim/Emacs','MATLAB', 
                     'Jupyter Notebook', 'None', 'Other']
IDE_usage.sort_values(["count"], ascending=False, inplace=True)

ax = sns.catplot(x = "count", y="IDE", data=IDE_usage, kind="bar", aspect=4/2, color="green")
plt.title('Integrated Development Environments (IDEs) used regualrly');

# %%
IDE_usage = pd.DataFrame(Nigeria.loc[:,list(Nigeria.columns[21:34])].count(), columns=["count"])
IDE_usage ["IDE"] = ['Jupyter', 'Rstudio', 'Visual Studio', 'VScode', 
                     'PyCharm', 'Spyder', 'Notepad++', 'Sublime Text', 'Vim/Emacs','MATLAB', 
                     'Jupyter Notebook', 'None', 'Other']
#IDE_usage.sort_values(["count"], ascending=False, inplace=True)

ax = sns.catplot(x = "count", y="IDE", data=IDE_usage, kind="bar", aspect=4/2, color="green")
plt.title('Integrated Development Environments (IDEs) used regualrly');

# %%
IDE_usage
# Out:
#             count               IDE
# Q9_Part_11    431  Jupyter Notebook
# Q9_Part_4     226            VScode
# Q9_Part_5     167           PyCharm
# Q9_Part_1     116           Jupyter
# Q9_Part_8      93      Sublime Text
# Q9_Part_2      91           Rstudio
# Q9_Part_3      89     Visual Studio
# Q9_Part_7      82         Notepad++
# Q9_Part_6      66            Spyder
# Q9_Part_10     42            MATLAB
# Q9_OTHER       31             Other
# Q9_Part_12     15              None
# Q9_Part_9       9         Vim/Emacs

# %%
Nigeria.columns[256:268]
# Out:
# Index(['Q42_Part_1', 'Q42_Part_2', 'Q42_Part_3', 'Q42_Part_4', 'Q42_Part_5',
#        'Q42_Part_6', 'Q42_Part_7', 'Q42_Part_8', 'Q42_Part_9', 'Q42_Part_10',
#        'Q42_Part_11', 'Q42_OTHER'],
#       dtype='object')

# %%
media_source = pd.DataFrame(Nigeria.loc[:,list(Nigeria.columns[256:268] )].count(), columns=["count"])
media_source ["media_source"] = ['Twitter', 'Email newsletters', 'Reddit', 'Kaggle', 'Course Forums',
       'YouTube', 'Podcasts', 'Blogs', 'Journal Publications', 'Slack Communities',
       'None', 'Other']
media_source.sort_values(["count"], ascending=False, inplace=True)

ax = sns.catplot(x = "count", y="media_source", data=media_source, kind="bar", aspect=4/2, color="green")
plt.title('Favourite media source for data science');

# %%
ml_years = pd.DataFrame(Nigeria['Q15']) 
ml_years = pd.DataFrame(ml_years.groupby(['Q15']).size())
ml_years.reset_index(inplace=True)
ml_years.columns = ['ml_years','count']
ml_years.sort_values(['count'],ascending = False, inplace =True)

ax = sns.catplot(x= 'ml_years', y= 'count', data= ml_years,aspect = 4/2, color ='green', kind = 'bar')
plt.title('Years of machine learning experience')
plt.xticks(rotation=90);

# %%
Nigeria.columns[72:90]
# Out:
# Index(['Q16_Part_1', 'Q16_Part_2', 'Q16_Part_3', 'Q16_Part_4', 'Q16_Part_5',
#        'Q16_Part_6', 'Q16_Part_7', 'Q16_Part_8', 'Q16_Part_9', 'Q16_Part_10',
#        'Q16_Part_11', 'Q16_Part_12', 'Q16_Part_13', 'Q16_Part_14',
#        'Q16_Part_15', 'Q16_Part_16', 'Q16_Part_17', 'Q16_OTHER'],
#       dtype='object')

# %%
ml_framework = pd.DataFrame(Nigeria.loc[:,list(Nigeria.columns[72:90] )].count(), columns=["count"])
ml_framework ["ml_framework"] = ['Scikit-learn', 'TensorFlow', 'Keras', 'PyTorch', 'Fast.ai',
       'MXNet', 'Xgboost', 'LightGBM', 'CatBoost', 'Prophet', "H2O 3", "Caret", "Tidymodels", "JAX",
                                "PyTorch Lightning", "Huggingface",
       'None', 'Other']
ml_framework.sort_values(["count"], ascending=False, inplace=True)

ax = sns.catplot(x = "count", y="ml_framework", data=ml_framework, kind="bar", aspect=4/2, color="green")
plt.title('Most common machine learning frameworks');

# %%
Nigeria.columns[90:102]
# Out:
# Index(['Q17_Part_1', 'Q17_Part_2', 'Q17_Part_3', 'Q17_Part_4', 'Q17_Part_5',
#        'Q17_Part_6', 'Q17_Part_7', 'Q17_Part_8', 'Q17_Part_9', 'Q17_Part_10',
#        'Q17_Part_11', 'Q17_OTHER'],
#       dtype='object')

# %%
ml_algorithm = pd.DataFrame(Nigeria.loc[:,list(Nigeria.columns[90:102])].count(), columns=["count"])
ml_algorithm ["ml_algorithm"] = ['Linear or Logistic Regression', 'Decision Trees or Random Forests', 
                                 'Gradient Boosting Machines (xgboost, lightgbm, etc)', 
                                 'Bayesian Approaches', 'Evolutionary Approaches',
                                 'Dense Neural Networks (MLPs, etc)', 
                                 'Convolutional Neural Networks', 'Generative Adversarial Networks', 
                                 'Recurrent Neural Networks', 'Transformer Networks (BERT, gpt-3, etc)', 
       'None', 'Other']
ml_algorithm.sort_values(["count"], ascending=False, inplace=True)

ax = sns.catplot(x = "count", y="ml_algorithm", data=ml_algorithm, kind="bar", aspect=4/2, color="green")
plt.title('Most common machine learning algorithms');

# %%
industry = pd.DataFrame(Nigeria['Q20']) 
industry = pd.DataFrame(industry.groupby(['Q20']).size())
industry.reset_index(inplace=True)
industry.columns = ['industry','count']
industry.sort_values(['count'],ascending = False, inplace =True)

ax = sns.catplot(x= 'industry', y= 'count', data= industry,aspect = 4/2, color ='green', kind = 'bar')
plt.title('Industry of Nigeria Kagglers')
plt.xticks(rotation=90);

# %%
(Nigeria.columns[165:186])
# Out:
# Index(['Q32_A_Part_1', 'Q32_A_Part_2', 'Q32_A_Part_3', 'Q32_A_Part_4',
#        'Q32_A_Part_5', 'Q32_A_Part_6', 'Q32_A_Part_7', 'Q32_A_Part_8',
#        'Q32_A_Part_9', 'Q32_A_Part_10', 'Q32_A_Part_11', 'Q32_A_Part_12',
#        'Q32_A_Part_13', 'Q32_A_Part_14', 'Q32_A_Part_15', 'Q32_A_Part_16',
#        'Q32_A_Part_17', 'Q32_A_Part_18', 'Q32_A_Part_19', 'Q32_A_Part_20',
#        'Q32_A_OTHER'],
#       dtype='object')

# %%
database = pd.DataFrame(Nigeria.loc[:,list(Nigeria.columns[165:186])].count(), columns=["count"])
database ["database"] = ['MySQL', 'PostgreSQL', 'SQLite', 
                                 'Oracle Database', 'MongoDB',
                                 'Snowflake', 'IBM Db2', 'Microsoft SQL Server', 
                                 'Microsoft Azure SQL Database', 'Microsoft Azure Cosmos DB',
                         "Amazon Redshift", "Amazon Aurora", "Amazon RDS", "Amazon DynamoDB",
                         "Google Cloud BigQuery", "Google Cloud SQL", "Google Cloud Firestore",
                         "Google Cloud BigTable", "Google Cloud Spanner",
       'None', 'Other']
database.sort_values(["count"], ascending=False, inplace=True)

ax = sns.catplot(x = "count", y="database", data=database, kind="bar", aspect=4/2, color="green")
plt.title('Most common database');
