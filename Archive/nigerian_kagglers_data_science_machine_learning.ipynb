# %% [markdown]
# # Exploratory Analysis and Visualisation of Nigerian Kagglers using Kaggle's 2021 Data Science and Machine Learning survey

# %% [markdown]
# # Import relevant libraries

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt 

import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
df = pd.read_csv("kaggle_survey_2021_responses.csv", low_memory=False)
df = df.drop([0], axis=0) #this removes the row with the questions

# enable showing all columns and rows
pd.set_option('display.max_columns', None) #show all columns
#pd.set_option('display.max_rows', None)
#pd.set_option('display.width', None)
#pd.set_option('display.max_colwidth', None)

colors_ng = "green" #chart color for Nigerian Kagglers.
colors_rotw = "gold" #chart color for the rest of the world.

# %% [markdown]
# # The total number of responses globally was 25973

# %%
df.shape[0]
# Out:
# 25973

# %%
df[df.columns[3]].replace({'United Kingdom of Great Britain and Northern Ireland':'UK',
                           'Iran, Islamic Republic of...':'Iran',
                           'United Arab Emirates':'UAE',
                           'United States of America':'USA',
                           'Viet Nam':'Vietnam'}, inplace=True)

# %%
print(f" List of countries that participated in the Kaggle's 2021 Data Science and Machine Learning survey:\n{np.sort(df[df.columns[3]].unique())}\n")
# Out:
#  List of countries that participated in the Kaggle's 2021 Data Science and Machine Learning survey:
# ['Algeria' 'Argentina' 'Australia' 'Austria' 'Bangladesh' 'Belarus'
#  'Belgium' 'Brazil' 'Canada' 'Chile' 'China' 'Colombia' 'Czech Republic'
#  'Denmark' 'Ecuador' 'Egypt' 'Ethiopia' 'France' 'Germany' 'Ghana'
#  'Greece' 'Hong Kong (S.A.R.)' 'I do not wish to disclose my location'
#  'India' 'Indonesia' 'Iran' 'Iraq' 'Ireland' 'Israel' 'Italy' 'Japan'
#  'Kazakhstan' 'Kenya' 'Malaysia' 'Mexico' 'Morocco' 'Nepal' 'Netherlands'
#  'Nigeria' 'Norway' 'Other' 'Pakistan' 'Peru' 'Philippines' 'Poland'
#  'Portugal' 'Romania' 'Russia' 'Saudi Arabia' 'Singapore' 'South Africa'
#  'South Korea' 'Spain' 'Sri Lanka' 'Sweden' 'Switzerland' 'Taiwan'
#  'Thailand' 'Tunisia' 'Turkey' 'UAE' 'UK' 'USA' 'Uganda' 'Ukraine'
#  'Vietnam']

# %%
print(f" Total number of countries that participated in the Kaggle's 2021 Data Science and Machine Learning survey:\n{(len(np.sort(df[df.columns[3]].unique())) - 2)}\n")

#(-2 for "Other" & "I do not wish to disclose my location")
# Out:
#  Total number of countries that participated in the Kaggle's 2021 Data Science and Machine Learning survey:
# 64

# %% [markdown]
# # Top 10 countries with the most Kagglers

# %% [markdown]
# # In comparison to other countries,  Nigeria Kagglers make up about 2.7% and Nigeria ranks 7th

# %%
top10_countries = df['Q3'].value_counts(normalize=True, ascending=False) #Count the number of countries and express it as a fraction
top10_countries = top10_countries.drop(["Other"], axis=0) #drop "Other"
top10_countries = top10_countries.mul(100) #multiply the values by 100 (i.e. percentage)
top10_countries = top10_countries.rename("percentage (%)").reset_index()
top10_countries = top10_countries.rename(columns={"index":"country"})
top10_countries = top10_countries.head(10).round(decimals=1)



top10_countries["color"] = "gold" #color the others gold
top10_countries.loc[top10_countries["country"] == "Nigeria", ["color"]] = "green" #color Nigeria green

fig = px.bar(top10_countries, x="country", y="percentage (%)", text='percentage (%)', 
             title="Top 10 countries with the most Kagglers")
fig.update_traces(texttemplate='%{text:.2s}', textposition='outside', marker_color=top10_countries.color) 
fig.update_layout(uniformtext_minsize=8, uniformtext_mode='hide', plot_bgcolor = "white")

fig.show()
# Out:
# <div>                            <div id="62bf2f35-cb9b-408c-b72f-c861b1a5941e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("62bf2f35-cb9b-408c-b72f-c861b1a5941e")) {                    Plotly.newPlot(                        "62bf2f35-cb9b-408c-b72f-c861b1a5941e",                        [{"alignmentgroup": "True", "hovertemplate": "country=%{x}<br>percentage (%)=%{text}<extra></extra>", "legendgroup": "", "marker": {"color": ["gold", "gold", "gold", "gold", "gold", "gold", "green", "gold", "gold", "gold"]}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "text": [28.6, 10.2, 3.5, 3.1, 2.9, 2.9, 2.7, 2.1, 2.0, 1.9], "textposition": "outside", "texttemplate": "%{text:.2s}", "type": "bar", "x": ["India", "USA", "Japan", "China", "Brazil", "Russia", "Nigeria", "UK", "Pakistan", "Egypt"], "xaxis": "x", "y": [28.6, 10.2, 3.5, 3.1, 2.9, 2.9, 2.7, 2.1, 2.0, 1.9], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"tracegroupgap": 0}, "plot_bgcolor": "white", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.77 ...

# %%
top10_countries
# Out:
#     country  percentage (%)  color
# 0     India            28.6   gold
# 1       USA            10.2   gold
# 2     Japan             3.5   gold
# 3     China             3.1   gold
# 4    Brazil             2.9   gold
# 5    Russia             2.9   gold
# 6   Nigeria             2.7  green
# 7        UK             2.1   gold
# 8  Pakistan             2.0   gold
# 9     Egypt             1.9   gold

# %%
top10_countries = df['Q3'].value_counts(normalize=True,
                                        ascending=False).drop(["Other"], 
                                        axis=0).mul(100).rename("percentage (%)").reset_index(
).rename(columns={"index":"country"}).head(10).round(decimals=1)




#top10_countries = top10_countries.drop(["Other"], axis=0) #drop "Other"
#top10_countries = top10_countries.mul(100) #multiply the values by 100 (i.e. percentage)
#top10_countries = top10_countries.rename("percentage (%)").reset_index()
#top10_countries = top10_countries.rename(columns={"index":"country"})
#top10_countries = top10_countries.head(10).round(decimals=1)

top10_countries
# Out:
#     country  percentage (%)
# 0     India            28.6
# 1       USA            10.2
# 2     Japan             3.5
# 3     China             3.1
# 4    Brazil             2.9
# 5    Russia             2.9
# 6   Nigeria             2.7
# 7        UK             2.1
# 8  Pakistan             2.0
# 9     Egypt             1.9

# %% [markdown]
# # Africa

# %%
africa = ['Algeria', 'Egypt', 'Ethiopia','Ghana', 'Kenya', 'Morocco', 'Nigeria', 'South Africa', 
          'Tunisia', 'Uganda'] #List of African countries

africa_countries = df[df['Q3'].isin(africa)]
africa_countries = africa_countries["Q3"].value_counts(normalize=True, ascending=False) 
#Count the number of countries within Africa and express it as a fraction
africa_countries = africa_countries.mul(100) #multiply the values by 100 (i.e. percentage)
africa_countries = africa_countries.rename("percentage (%)").reset_index()
africa_countries = africa_countries.rename(columns={"index":"country"})
africa_countries = africa_countries.round(decimals=1) 


africa_countries["color"] = "gold" #color the others gold
africa_countries.loc[africa_countries["country"] == "Nigeria", ["color"]] = "green" #color Nigeria green

fig = px.bar(africa_countries, x="country", y="percentage (%)", text='percentage (%)', 
             title="Ranking of African countries with the most Kagglers")
fig.update_traces(texttemplate='%{text:.2s}', textposition='outside', marker_color=africa_countries.color) 
fig.update_layout(uniformtext_minsize=8, uniformtext_mode='hide', plot_bgcolor = "white")

fig.show()
# Out:
# <div>                            <div id="0317b5a3-9825-4f4e-8620-d82ca4f44110" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0317b5a3-9825-4f4e-8620-d82ca4f44110")) {                    Plotly.newPlot(                        "0317b5a3-9825-4f4e-8620-d82ca4f44110",                        [{"alignmentgroup": "True", "hovertemplate": "country=%{x}<br>percentage (%)=%{text}<extra></extra>", "legendgroup": "", "marker": {"color": ["green", "gold", "gold", "gold", "gold", "gold", "gold", "gold", "gold", "gold"]}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "text": [34.1, 23.4, 12.0, 7.1, 6.8, 5.3, 4.8, 2.3, 2.1, 2.1], "textposition": "outside", "texttemplate": "%{text:.2s}", "type": "bar", "x": ["Nigeria", "Egypt", "Kenya", "South Africa", "Morocco", "Tunisia", "Ghana", "Uganda", "Algeria", "Ethiopia"], "xaxis": "x", "y": [34.1, 23.4, 12.0, 7.1, 6.8, 5.3, 4.8, 2.3, 2.1, 2.1], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"tracegroupgap": 0}, "plot_bgcolor": "white", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666 ...

# %%
africa_countries
# Out:
#         country  percentage (%)
# 0       Nigeria            34.1
# 1         Egypt            23.4
# 2         Kenya            12.0
# 3  South Africa             7.1
# 4       Morocco             6.8
# 5       Tunisia             5.3
# 6         Ghana             4.8
# 7        Uganda             2.3
# 8       Algeria             2.1
# 9      Ethiopia             2.1

# %%
africa_countries["color"] = "gold" #color the others gold
africa_countries.loc[africa_countries["country"] == "Nigeria", ["color"]] = "green" #color Nigeria green

# %%
Cumulative_cases_plot = px.choropleth(africa_countries,
                    locations="country", #Spatial coordinates and corrseponds to a column in dataframe
                    color="percentage (%)", #Corresponding data in the dataframe
                    locationmode = 'country names', #location mode == One of ‘ISO-3’, ‘USA-states’, or ‘country names’ 
                    #locationmode == should match the type of data entries in "locations"
                    scope="africa", #limits the scope of the map to Africa
                    title ="African Kagglers",
                    hover_name="country",
                    color_continuous_scale = "Greens",
                   )
Cumulative_cases_plot.update_traces(marker_line_color="black") # line markers between states
Cumulative_cases_plot.show()
# Out:
# <div>                            <div id="257ee7b8-4b3a-4e7c-9a3a-bad5e16bbb33" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("257ee7b8-4b3a-4e7c-9a3a-bad5e16bbb33")) {                    Plotly.newPlot(                        "257ee7b8-4b3a-4e7c-9a3a-bad5e16bbb33",                        [{"coloraxis": "coloraxis", "geo": "geo", "hovertemplate": "<b>%{hovertext}</b><br><br>country=%{location}<br>percentage (%)=%{z}<extra></extra>", "hovertext": ["Nigeria", "Egypt", "Kenya", "South Africa", "Morocco", "Tunisia", "Ghana", "Uganda", "Algeria", "Ethiopia"], "locationmode": "country names", "locations": ["Nigeria", "Egypt", "Kenya", "South Africa", "Morocco", "Tunisia", "Ghana", "Uganda", "Algeria", "Ethiopia"], "marker": {"line": {"color": "black"}}, "name": "", "type": "choropleth", "z": [34.1, 23.4, 12.0, 7.1, 6.8, 5.3, 4.8, 2.3, 2.1, 2.1]}],                        {"coloraxis": {"colorbar": {"title": {"text": "percentage (%)"}}, "colorscale": [[0.0, "rgb(247,252,245)"], [0.125, "rgb(229,245,224)"], [0.25, "rgb(199,233,192)"], [0.375, "rgb(161,217,155)"], [0.5, "rgb(116,196,118)"], [0.625, "rgb(65,171,93)"], [0.75, "rgb(35,139,69)"], [0.875, "rgb(0,109,44)"], [1.0, "rgb(0,68,27)"]]}, "geo": {"center": {}, "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "scope": "africa"}, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}] ...

# %% [markdown]
# - Out of the 64 countries that took part in the Kaggle Survey, 10 countries are from Africa.
#
#
# - There are 54 countries within Africa, which means that less than 20 % completed the Kaggle survey.
#
#
# - Within Africa, Nigeria Kagglers make up 34% and and ranked number one in Africa. Fun fact - Nigeria is also the most populated country in Africa.
#
#
# - The top three African countries on Kaggle are Nigeria, Egypt and Kenya.

# %%
nigeria = df[df["Q3"] =="Nigeria"]

# %% [markdown]
# # Who are Nigerian Kagglers

# %% [markdown]
# # The total number of respondents from Nigeria was 702

# %%
nigeria.shape
# Out:
# (702, 369)

# %% [markdown]
# # Gender distribution of Nigerian Kagglers compared to the rest of the world

# %%
gender_distribution_ng = nigeria[nigeria["Q2"].isin(["Man", "Woman"])]
gender_distribution_ng = gender_distribution_ng['Q2'].value_counts(normalize=True, ascending=False)
gender_distribution_ng = gender_distribution_ng.mul(100)
gender_distribution_ng = gender_distribution_ng.round(decimals=1)
gender_distribution_ng = pd.DataFrame(data=gender_distribution_ng)
gender_distribution_ng.reset_index(inplace=True)
gender_distribution_ng.columns = ["gender","percentage(%)"] 

rest_of_the_world = df[df["Q3"] !="Nigeria"]
gender_distribution_rotw = rest_of_the_world[rest_of_the_world["Q2"].isin(["Man", "Woman"])]
gender_distribution_rotw = gender_distribution_rotw['Q2'].value_counts(normalize=True, ascending=False)
gender_distribution_rotw = gender_distribution_rotw.mul(100)
gender_distribution_rotw = gender_distribution_rotw.round(decimals=1) 
gender_distribution_rotw = pd.DataFrame(data=gender_distribution_rotw)
gender_distribution_rotw.reset_index(inplace=True)
gender_distribution_rotw.columns = ["gender","percentage(%)"] 

fig = go.Figure()

fig.add_trace(go.Bar(x=gender_distribution_ng["gender"], y=gender_distribution_ng["percentage(%)"], 
                     name="Nigerian Kagglers", marker_color=colors_ng,
                     text=gender_distribution_ng["percentage(%)"],
                     textposition='outside', texttemplate='%{text:.2s}'))

fig.add_trace(go.Bar(x=gender_distribution_rotw["gender"], y=gender_distribution_rotw["percentage(%)"], 
                     name="Rest of the world", marker_color=colors_rotw,
                     text=gender_distribution_rotw["percentage(%)"],
                     textposition='outside', texttemplate='%{text:.2s}'))


fig.update_layout(uniformtext_minsize=8, uniformtext_mode='hide', plot_bgcolor = "white")
fig.show()
# Out:
# <div>                            <div id="790f0d25-c824-4d77-9460-7d0a79b428c4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("790f0d25-c824-4d77-9460-7d0a79b428c4")) {                    Plotly.newPlot(                        "790f0d25-c824-4d77-9460-7d0a79b428c4",                        [{"marker": {"color": "green"}, "name": "Nigerian Kagglers", "text": [84.7, 15.3], "textposition": "outside", "texttemplate": "%{text:.2s}", "type": "bar", "x": ["Man", "Woman"], "y": [84.7, 15.3]}, {"marker": {"color": "gold"}, "name": "Rest of the world", "text": [80.7, 19.3], "textposition": "outside", "texttemplate": "%{text:.2s}", "type": "bar", "x": ["Man", "Woman"], "y": [80.7, 19.3]}],                        {"plot_bgcolor": "white", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoord ...

# %%
# 15% of Nigerian Kagglers are women and 85% are men 

#Compared to the rest of the world, the percentage of female Kagglers in Nigeria (15%) 
#is lower than the rest of the world (19%)

# %% [markdown]
# # What do Nigerian Kagglers do?

# %%
job_ng = nigeria["Q5"].value_counts(normalize=True, ascending=False) 
job_ng = job_ng.mul(100)
job_ng = job_ng.round(decimals=1)
job_ng = pd.DataFrame(data=job_ng)
job_ng.reset_index(inplace=True)
job_ng.columns = ["role","percentage (%)"] 

fig = px.bar(job_ng, x="role", y="percentage (%)", text='percentage (%)', 
             title="Job roles of Nigerian Kagglers")
fig.update_traces(texttemplate='%{text:.2s}', textposition='outside', marker_color=colors_ng, ) 
fig.update_layout(uniformtext_minsize=8, uniformtext_mode='hide', plot_bgcolor = "white")
fig.show()
# Out:
# <div>                            <div id="3eb710c7-f1ab-47e7-ab9d-1d73f2dab14a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3eb710c7-f1ab-47e7-ab9d-1d73f2dab14a")) {                    Plotly.newPlot(                        "3eb710c7-f1ab-47e7-ab9d-1d73f2dab14a",                        [{"alignmentgroup": "True", "hovertemplate": "role=%{x}<br>percentage (%)=%{text}<extra></extra>", "legendgroup": "", "marker": {"color": "green"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "text": [19.8, 14.5, 13.5, 13.1, 8.5, 6.1, 6.1, 5.4, 4.3, 2.8, 2.7, 1.9, 0.9, 0.3], "textposition": "outside", "texttemplate": "%{text:.2s}", "type": "bar", "x": ["Student", "Data Analyst", "Data Scientist", "Currently not employed", "Other", "Software Engineer", "Machine Learning Engineer", "Research Scientist", "Business Analyst", "Program/Project Manager", "Statistician", "Data Engineer", "Product Manager", "DBA/Database Engineer"], "xaxis": "x", "y": [19.8, 14.5, 13.5, 13.1, 8.5, 6.1, 6.1, 5.4, 4.3, 2.8, 2.7, 1.9, 0.9, 0.3], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"tracegroupgap": 0}, "plot_bgcolor": "white", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222 ...

# %%
job_ng
# Out:
#                          role  percentage (%)
# 0                     Student            19.8
# 1                Data Analyst            14.5
# 2              Data Scientist            13.5
# 3      Currently not employed            13.1
# 4                       Other             8.5
# 5           Software Engineer             6.1
# 6   Machine Learning Engineer             6.1
# 7          Research Scientist             5.4
# 8            Business Analyst             4.3
# 9     Program/Project Manager             2.8
# 10               Statistician             2.7
# 11              Data Engineer             1.9
# 12            Product Manager             0.9
# 13      DBA/Database Engineer             0.3

# %%
nigeria["Q5"].value_counts(normalize=True, ascending=False).mul(100).round(decimals=1).reset_index()
# Out:
#                         index    Q5
# 0                     Student  19.8
# 1                Data Analyst  14.5
# 2              Data Scientist  13.5
# 3      Currently not employed  13.1
# 4                       Other   8.5
# 5           Software Engineer   6.1
# 6   Machine Learning Engineer   6.1
# 7          Research Scientist   5.4
# 8            Business Analyst   4.3
# 9     Program/Project Manager   2.8
# 10               Statistician   2.7
# 11              Data Engineer   1.9
# 12            Product Manager   0.9
# 13      DBA/Database Engineer   0.3

# %%
#Most Nigerian Kagglers are Students, Data Analysts and Data Scientists

# %%
job_rotw = rest_of_the_world["Q5"].value_counts(normalize=True, ascending=False) 
job_rotw = job_rotw.mul(100)
job_rotw = job_rotw.round(decimals=1)
job_rotw = pd.DataFrame(data=job_rotw)
job_rotw.reset_index(inplace=True)
job_rotw.columns = ["role","percentage (%)"] 

fig = px.bar(job_rotw, x="role", y="percentage (%)", text='percentage (%)',
            title="Job roles for the rest of the world")
fig.update_traces(texttemplate='%{text:.2s}', textposition='outside', marker_color=colors_rotw,) 
fig.update_layout(uniformtext_minsize=8, uniformtext_mode='hide', plot_bgcolor = "white")
fig.show()
# Out:
# <div>                            <div id="8d82489a-4de5-4a34-97ba-951e68004a57" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8d82489a-4de5-4a34-97ba-951e68004a57")) {                    Plotly.newPlot(                        "8d82489a-4de5-4a34-97ba-951e68004a57",                        [{"alignmentgroup": "True", "hovertemplate": "role=%{x}<br>percentage (%)=%{text}<extra></extra>", "legendgroup": "", "marker": {"color": "gold"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "text": [26.4, 13.9, 9.5, 9.2, 8.7, 7.5, 5.9, 5.8, 3.7, 3.3, 2.6, 1.2, 1.2, 0.7, 0.4], "textposition": "outside", "texttemplate": "%{text:.2s}", "type": "bar", "x": ["Student", "Data Scientist", "Software Engineer", "Other", "Data Analyst", "Currently not employed", "Research Scientist", "Machine Learning Engineer", "Business Analyst", "Program/Project Manager", "Data Engineer", "Product Manager", "Statistician", "DBA/Database Engineer", "Developer Relations/Advocacy"], "xaxis": "x", "y": [26.4, 13.9, 9.5, 9.2, 8.7, 7.5, 5.9, 5.8, 3.7, 3.3, 2.6, 1.2, 1.2, 0.7, 0.4], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"tracegroupgap": 0}, "plot_bgcolor": "white", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.111111111111 ...

# %%
#Similar to the  rest of the world, Students form the majority of Nigerian Kagglers.

#Also, Software Engineers rank higher (3rd) compared to Kagglers from Nigeria (6th).

# %% [markdown]
# # Age distribution of Nigerian Kagglers

# %%
age_ng = nigeria["Q1"].value_counts(normalize=True) 
age_ng = age_ng.mul(100)
age_ng = age_ng.round(decimals=1)
age_ng = pd.DataFrame(data=age_ng)
age_ng.reset_index(inplace=True)
age_ng.columns = ["age","percentage (%)"] 
age_ng.sort_values(by="age", inplace=True)


fig = px.bar(age_ng, x="age", y="percentage (%)", text='percentage (%)', 
             title="Age of Nigerian Kagglers")
fig.update_traces(texttemplate='%{text:.2s}', textposition='outside', marker_color=colors_ng, ) 
fig.update_layout(uniformtext_minsize=8, uniformtext_mode='hide', plot_bgcolor = "white")

fig.show()
# Out:
# <div>                            <div id="354bcb84-3538-4dd4-9087-86fb2aeee8d8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("354bcb84-3538-4dd4-9087-86fb2aeee8d8")) {                    Plotly.newPlot(                        "354bcb84-3538-4dd4-9087-86fb2aeee8d8",                        [{"alignmentgroup": "True", "hovertemplate": "age=%{x}<br>percentage (%)=%{text}<extra></extra>", "legendgroup": "", "marker": {"color": "green"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "text": [12.4, 18.5, 29.5, 16.4, 13.7, 6.0, 2.7, 0.6, 0.3], "textposition": "outside", "texttemplate": "%{text:.2s}", "type": "bar", "x": ["18-21", "22-24", "25-29", "30-34", "35-39", "40-44", "45-49", "50-54", "60-69"], "xaxis": "x", "y": [12.4, 18.5, 29.5, 16.4, 13.7, 6.0, 2.7, 0.6, 0.3], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"tracegroupgap": 0}, "plot_bgcolor": "white", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "hist ...

# %%
#The largest proportion (30%) of Nigerian Kagglers are in the age range of 25 - 29 

#About 65% of Nigerian Kagglers are within the age of range 22 - 34

#91% of Nigerian Kagglers are younger than 40.

# %%
age_rotw = rest_of_the_world["Q1"].value_counts(normalize=True) 
age_rotw = age_rotw.mul(100)
age_rotw = age_rotw.round(decimals=1)
age_rotw = pd.DataFrame(data=age_rotw)
age_rotw.reset_index(inplace=True)
age_rotw.columns = ["age","percentage (%)"] 
age_rotw.sort_values(by="age", inplace=True)


fig = px.bar(age_rotw, x="age", y="percentage (%)", text='percentage (%)', 
             title="Age range for the rest of the world") 
fig.update_traces(texttemplate='%{text:.3s}', textposition='outside', marker_color=colors_rotw, ) 
fig.update_layout(uniformtext_minsize=8, uniformtext_mode='hide', plot_bgcolor = "white")
fig.show()
# Out:
# <div>                            <div id="78e6b831-82d0-430a-a05e-4c2c14dd134e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("78e6b831-82d0-430a-a05e-4c2c14dd134e")) {                    Plotly.newPlot(                        "78e6b831-82d0-430a-a05e-4c2c14dd134e",                        [{"alignmentgroup": "True", "hovertemplate": "age=%{x}<br>percentage (%)=%{text}<extra></extra>", "legendgroup": "", "marker": {"color": "gold"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "text": [19.0, 18.1, 18.7, 13.2, 9.5, 7.3, 5.4, 3.8, 2.3, 2.2, 0.5], "textposition": "outside", "texttemplate": "%{text:.3s}", "type": "bar", "x": ["18-21", "22-24", "25-29", "30-34", "35-39", "40-44", "45-49", "50-54", "55-59", "60-69", "70+"], "xaxis": "x", "y": [19.0, 18.1, 18.7, 13.2, 9.5, 7.3, 5.4, 3.8, 2.3, 2.2, 0.5], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"tracegroupgap": 0}, "plot_bgcolor": "white", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], ...

# %%
#Look at the rest of the world in general, the higher the age, the lower the proportion/percentage. 

#The largest proportion (19%) for the rest of the world falls between 18 and 21.

#In general, Kagglers worldwide are relatively young.

# %% [markdown]
# # Education Level of Nigerian Kagglers

# %%
education_ng = nigeria["Q4"].value_counts(normalize=True) 
education_ng = education_ng.mul(100)
education_ng = education_ng.round(decimals=1)
education_ng = pd.DataFrame(data=education_ng)
education_ng.reset_index(inplace=True)
education_ng.columns = ["education", "percentage (%)"]

education_order = ["No formal education past high school", 
                             "Some college/university study without earning a bachelor’s degree",
"Bachelor’s degree", "Master’s degree", "Doctoral degree", "Professional doctorate", "I prefer not to answer"]

education_ng["education"] = pd.Categorical(education_ng["education"], categories=education_order)

education_ng.sort_values(by="education", inplace=True)

labels_ng = education_ng['education']
values_ng = education_ng["percentage (%)"]


fig = px.pie(values=values_ng, names=labels_ng, color_discrete_sequence=px.colors.sequential.Greens_r, 
            title="Highest formal education of Nigerian Kagglers") 

fig.update_traces(textposition='inside', textinfo='percent+label')  

fig.update_layout(uniformtext_minsize=10, uniformtext_mode='hide')

fig.show()
# Out:
# <div>                            <div id="8ec3bd57-6be6-40d5-88c1-470dcb914213" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8ec3bd57-6be6-40d5-88c1-470dcb914213")) {                    Plotly.newPlot(                        "8ec3bd57-6be6-40d5-88c1-470dcb914213",                        [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "label=%{label}<br>value=%{value}<extra></extra>", "labels": ["No formal education past high school", "Some college/university study without earning a bachelor\u2019s degree", "Bachelor\u2019s degree", "Master\u2019s degree", "Doctoral degree", "Professional doctorate", "I prefer not to answer"], "legendgroup": "", "name": "", "showlegend": true, "textinfo": "percent+label", "textposition": "inside", "type": "pie", "values": [0.7, 5.7, 51.7, 35.6, 4.7, 0.4, 1.1]}],                        {"legend": {"tracegroupgap": 0}, "piecolorway": ["rgb(0,68,27)", "rgb(0,109,44)", "rgb(35,139,69)", "rgb(65,171,93)", "rgb(116,196,118)", "rgb(161,217,155)", "rgb(199,233,192)", "rgb(229,245,224)", "rgb(247,252,245)"], "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.555555555555555 ...

# %%
education_rotw = rest_of_the_world["Q4"].value_counts(normalize=True) 
education_rotw  = education_rotw .mul(100)
education_rotw  = education_rotw .round(decimals=1)
education_rotw  = pd.DataFrame(data=education_rotw )
education_rotw .reset_index(inplace=True)
education_rotw.columns = ["education", "percentage (%)"]

education_order = ["No formal education past high school", 
                             "Some college/university study without earning a bachelor’s degree",
"Bachelor’s degree", "Master’s degree", "Doctoral degree", "Professional doctorate", "I prefer not to answer"]

education_rotw["education"] = pd.Categorical(education_rotw["education"], categories=education_order)

education_rotw.sort_values(by="education", inplace=True)


labels_rotw = education_rotw['education']
values_rotw = education_rotw["percentage (%)"]


fig = px.pie(values=values_rotw, names=labels_rotw, color_discrete_sequence=px.colors.sequential.YlOrBr_r, 
            title="Highest formal education for the rest of the world") 

fig.update_traces(textposition='inside', textinfo='percent+label')  

fig.update_layout(uniformtext_minsize=10, uniformtext_mode='hide')

fig.show()
# Out:
# <div>                            <div id="9964daee-1a08-487b-89aa-d873421e28fb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9964daee-1a08-487b-89aa-d873421e28fb")) {                    Plotly.newPlot(                        "9964daee-1a08-487b-89aa-d873421e28fb",                        [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "label=%{label}<br>value=%{value}<extra></extra>", "labels": ["No formal education past high school", "Some college/university study without earning a bachelor\u2019s degree", "Bachelor\u2019s degree", "Master\u2019s degree", "Doctoral degree", "Professional doctorate", "I prefer not to answer"], "legendgroup": "", "name": "", "showlegend": true, "textinfo": "percent+label", "textposition": "inside", "type": "pie", "values": [1.6, 6.7, 37.8, 39.1, 10.9, 1.4, 2.4]}],                        {"legend": {"tracegroupgap": 0}, "piecolorway": ["rgb(102,37,6)", "rgb(153,52,4)", "rgb(204,76,2)", "rgb(236,112,20)", "rgb(254,153,41)", "rgb(254,196,79)", "rgb(254,227,145)", "rgb(255,247,188)", "rgb(255,255,229)"], "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.555555555555555 ...

# %%
#The most common education level for Nigerian Kagglers is a Bachelor's degree (52%). 

#About 93% of Nigerian Kagglers have at least a Bachelor's degree.

#This is slightly higher than the rest of the world of 89%

# %% [markdown]
# # Industry of Nigeria Kagglers

# %%
industry_ng = nigeria["Q20"].value_counts(normalize=True) 
industry_ng = industry_ng.mul(100)
industry_ng = industry_ng.round(decimals=1)
industry_ng = pd.DataFrame(data=industry_ng)
industry_ng.reset_index(inplace=True)
industry_ng.columns = ["industry","percentage (%)"] 

fig = px.bar(industry_ng, x="industry", y="percentage (%)", text='percentage (%)', 
             title="Industry of Nigerian Kagglers")
fig.update_traces(texttemplate='%{text:.2s}', textposition='auto', marker_color=colors_ng, ) 
fig.update_layout(uniformtext_minsize=8, uniformtext_mode='hide', plot_bgcolor = "white")
fig.show()
# Out:
# <div>                            <div id="389d5fb9-e8cd-41eb-af3a-d39dd2593eac" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("389d5fb9-e8cd-41eb-af3a-d39dd2593eac")) {                    Plotly.newPlot(                        "389d5fb9-e8cd-41eb-af3a-d39dd2593eac",                        [{"alignmentgroup": "True", "hovertemplate": "industry=%{x}<br>percentage (%)=%{text}<extra></extra>", "legendgroup": "", "marker": {"color": "green"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "text": [23.7, 19.6, 12.7, 7.7, 5.9, 5.7, 5.1, 4.0, 3.5, 2.4, 2.4, 1.5, 1.3, 1.3, 1.1, 0.9, 0.7, 0.4], "textposition": "auto", "texttemplate": "%{text:.2s}", "type": "bar", "x": ["Academics/Education", "Computers/Technology", "Accounting/Finance", "Other", "Energy/Mining", "Non-profit/Service", "Medical/Pharmaceutical", "Government/Public Service", "Retail/Sales", "Marketing/CRM", "Online Service/Internet-based Services", "Manufacturing/Fabrication", "Broadcasting/Communications", "Insurance/Risk Assessment", "Online Business/Internet-based Sales", "Hospitality/Entertainment/Sports", "Shipping/Transportation", "Military/Security/Defense"], "xaxis": "x", "y": [23.7, 19.6, 12.7, 7.7, 5.9, 5.7, 5.1, 4.0, 3.5, 2.4, 2.4, 1.5, 1.3, 1.3, 1.1, 0.9, 0.7, 0.4], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"tracegroupgap": 0}, "plot_bgcolor": "white", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [ ...

# %%
#Most Nigeria Kagglers work in the following sectors:
    #Academics/Education
    #Computers/Technology
    #Accounting/Finance
    
#These industries are also in line with the rest of the world, however, Computers/Technology ranks as number one in the rest of the world.

# %%
industry_rotw = rest_of_the_world["Q20"].value_counts(normalize=True) 
industry_rotw = industry_rotw.mul(100)
industry_rotw = industry_rotw.round(decimals=1)
industry_rotw = pd.DataFrame(data=industry_rotw)
industry_rotw.reset_index(inplace=True)
industry_rotw.columns = ["industry","percentage (%)"] 

fig = px.bar(industry_rotw, x="industry", y="percentage (%)", text='percentage (%)', 
             title="Industry of other Kagglers (rest of the world)")
fig.update_traces(texttemplate='%{text:.2s}', textposition='auto', marker_color=colors_rotw) 
fig.update_layout(uniformtext_minsize=8, uniformtext_mode='hide', plot_bgcolor = "white")
fig.show()
# Out:
# <div>                            <div id="832b14f0-1d0c-4935-a978-b88fad24b879" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("832b14f0-1d0c-4935-a978-b88fad24b879")) {                    Plotly.newPlot(                        "832b14f0-1d0c-4935-a978-b88fad24b879",                        [{"alignmentgroup": "True", "hovertemplate": "industry=%{x}<br>percentage (%)=%{text}<extra></extra>", "legendgroup": "", "marker": {"color": "gold"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "text": [25.1, 19.6, 8.8, 6.9, 5.5, 4.7, 4.5, 3.6, 3.3, 3.3, 2.6, 2.3, 2.0, 2.0, 1.7, 1.7, 1.2, 1.1], "textposition": "auto", "texttemplate": "%{text:.2s}", "type": "bar", "x": ["Computers/Technology", "Academics/Education", "Accounting/Finance", "Other", "Manufacturing/Fabrication", "Medical/Pharmaceutical", "Government/Public Service", "Online Service/Internet-based Services", "Energy/Mining", "Retail/Sales", "Insurance/Risk Assessment", "Marketing/CRM", "Broadcasting/Communications", "Shipping/Transportation", "Non-profit/Service", "Online Business/Internet-based Sales", "Military/Security/Defense", "Hospitality/Entertainment/Sports"], "xaxis": "x", "y": [25.1, 19.6, 8.8, 6.9, 5.5, 4.7, 4.5, 3.6, 3.3, 3.3, 2.6, 2.3, 2.0, 2.0, 1.7, 1.7, 1.2, 1.1], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"tracegroupgap": 0}, "plot_bgcolor": "white", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8 ...

# %% [markdown]
# # How much do Nigerian Kagglers earn?

# %%
salary_ng = nigeria["Q25"].value_counts(normalize=True) 
salary_ng = salary_ng.mul(100)
salary_ng = salary_ng.round(decimals=1)
salary_ng = pd.DataFrame(data=salary_ng)
salary_ng.reset_index(inplace=True)
salary_ng.columns = ["salary","percentage (%)"] 

salary_order = ["$0-999", "1,000-1,999", "2,000-2,999", "3,000-3,999", "4,000-4,999", "5,000-7,499",
               "7,500-9,999", "10,000-14,999", "15,000-19,999", "20,000-24,999", "25,000-29,999",
                "30,000-39,999", "40,000-49,999", "50,000-59,999", "60,000-69,999", "70,000-79,999",
                "80,000-89,999", "90,000-99,999", "100,000-124,999", "150,000-199,999", "200,000-249,999",
                ">$1,000,000"]

salary_ng["salary"] = pd.Categorical(salary_ng["salary"], categories=salary_order)
salary_ng.sort_values(by="salary", inplace=True)

fig = px.bar(salary_ng, x="salary", y="percentage (%)", text='percentage (%)', 
             title="Annual salary of Nigerian Kagglers")
fig.update_traces(texttemplate='%{text:.2s}', textposition='outside', marker_color=colors_ng, ) 
fig.update_layout(uniformtext_minsize=8, uniformtext_mode='hide', plot_bgcolor = "white")
fig.show()
# Out:
# <div>                            <div id="7d3c2729-ee47-409c-a2cd-80a0af6b64f1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7d3c2729-ee47-409c-a2cd-80a0af6b64f1")) {                    Plotly.newPlot(                        "7d3c2729-ee47-409c-a2cd-80a0af6b64f1",                        [{"alignmentgroup": "True", "hovertemplate": "salary=%{x}<br>percentage (%)=%{text}<extra></extra>", "legendgroup": "", "marker": {"color": "green"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "text": [45.3, 14.3, 9.2, 4.2, 4.4, 5.3, 2.5, 5.1, 1.6, 1.4, 0.7, 0.7, 1.2, 0.2, 1.2, 0.5, 0.7, 0.2, 0.2, 0.7, 0.2, 0.2], "textposition": "outside", "texttemplate": "%{text:.2s}", "type": "bar", "x": ["$0-999", "1,000-1,999", "2,000-2,999", "3,000-3,999", "4,000-4,999", "5,000-7,499", "7,500-9,999", "10,000-14,999", "15,000-19,999", "20,000-24,999", "25,000-29,999", "30,000-39,999", "40,000-49,999", "50,000-59,999", "60,000-69,999", "70,000-79,999", "80,000-89,999", "90,000-99,999", "100,000-124,999", "150,000-199,999", "200,000-249,999", ">$1,000,000"], "xaxis": "x", "y": [45.3, 14.3, 9.2, 4.2, 4.4, 5.3, 2.5, 5.1, 1.6, 1.4, 0.7, 0.7, 1.2, 0.2, 1.2, 0.5, 0.7, 0.2, 0.2, 0.7, 0.2, 0.2], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"tracegroupgap": 0}, "plot_bgcolor": "white", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2 ...

# %% [markdown]
#  - Considering that annual salary above takes into consideration all the job roles (including students), let's investigate the salary distribution across the three main job titles (Data Analyst, Data Scientist and Software Engineer)

# %% [markdown]
# # Annual salary of Nigerian Kagglers that are Data Analysts

# %%
nigeria_data_analyst = nigeria[nigeria["Q5"]=="Data Analyst"] #fi;ter Nigerian Kagglers that are Data Analysts

nigeria_data_analyst = nigeria_data_analyst["Q25"].value_counts(normalize=True) 
nigeria_data_analyst = nigeria_data_analyst.mul(100)
nigeria_data_analyst = nigeria_data_analyst.round(decimals=1)
nigeria_data_analyst = pd.DataFrame(data=nigeria_data_analyst)
nigeria_data_analyst.reset_index(inplace=True)
nigeria_data_analyst.columns = ["salary","percentage (%)"] 

salary_order = ["$0-999", "1,000-1,999", "2,000-2,999", "3,000-3,999", "4,000-4,999", "5,000-7,499",
              "7,500-9,999", "10,000-14,999", "15,000-19,999", "20,000-24,999", "25,000-29,999",
               "30,000-39,999", "40,000-49,999", "50,000-59,999", "60,000-69,999", "70,000-79,999",
                "80,000-89,999", "90,000-99,999", "100,000-124,999", "150,000-199,999", "200,000-249,999",
               ">$1,000,000"]

nigeria_data_analyst["salary"] = pd.Categorical(nigeria_data_analyst["salary"], categories=salary_order)
nigeria_data_analyst.sort_values(by="salary", inplace=True)

fig = px.bar(nigeria_data_analyst, x="salary", y="percentage (%)", text='percentage (%)', 
             title="Annual salary of Nigerian Kagglers that are Data Analysts")
fig.update_traces(texttemplate='%{text:.2s}', textposition='outside', marker_color=colors_ng, ) 
fig.update_layout(uniformtext_minsize=8, uniformtext_mode='hide', plot_bgcolor = "white")
fig.show()
# Out:
# <div>                            <div id="1cf72d5d-0325-495d-8223-dd0ada5bc8ef" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1cf72d5d-0325-495d-8223-dd0ada5bc8ef")) {                    Plotly.newPlot(                        "1cf72d5d-0325-495d-8223-dd0ada5bc8ef",                        [{"alignmentgroup": "True", "hovertemplate": "salary=%{x}<br>percentage (%)=%{text}<extra></extra>", "legendgroup": "", "marker": {"color": "green"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "text": [48.4, 18.3, 4.3, 2.2, 6.5, 5.4, 4.3, 4.3, 3.2, 2.2, 1.1], "textposition": "outside", "texttemplate": "%{text:.2s}", "type": "bar", "x": ["$0-999", "1,000-1,999", "2,000-2,999", "3,000-3,999", "5,000-7,499", "7,500-9,999", "10,000-14,999", "15,000-19,999", "20,000-24,999", "40,000-49,999", "150,000-199,999"], "xaxis": "x", "y": [48.4, 18.3, 4.3, 2.2, 6.5, 5.4, 4.3, 4.3, 3.2, 2.2, 1.1], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"tracegroupgap": 0}, "plot_bgcolor": "white", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "# ...

# %% [markdown]
# # Annual salary of Nigerian Kagglers that are Data Scientists

# %%
nigeria_data_scientist = nigeria[nigeria["Q5"]=="Data Scientist"]


nigeria_data_scientist = nigeria_data_scientist["Q25"].value_counts(normalize=True) 
nigeria_data_scientist = nigeria_data_scientist.mul(100)
nigeria_data_scientist = nigeria_data_scientist.round(decimals=1)
nigeria_data_scientist = pd.DataFrame(data=nigeria_data_scientist)
nigeria_data_scientist.reset_index(inplace=True)
nigeria_data_scientist.columns = ["salary","percentage (%)"] 

salary_order = ["$0-999", "1,000-1,999", "2,000-2,999", "3,000-3,999", "4,000-4,999", "5,000-7,499",
              "7,500-9,999", "10,000-14,999", "15,000-19,999", "20,000-24,999", "25,000-29,999",
                "30,000-39,999", "40,000-49,999", "50,000-59,999", "60,000-69,999", "70,000-79,999",
                "80,000-89,999", "90,000-99,999", "100,000-124,999", "150,000-199,999", "200,000-249,999",
               ">$1,000,000"]

nigeria_data_scientist["salary"] = pd.Categorical(nigeria_data_scientist["salary"], categories=salary_order)
nigeria_data_scientist.sort_values(by="salary", inplace=True)

fig = px.bar(nigeria_data_scientist, x="salary", y="percentage (%)", text='percentage (%)', 
             title="Annual salary of Nigerian Kagglers that are Data Scientists")
fig.update_traces(texttemplate='%{text:.2s}', textposition='outside', marker_color=colors_ng, ) 
fig.update_layout(uniformtext_minsize=8, uniformtext_mode='hide', plot_bgcolor = "white")
fig.show()
# Out:
# <div>                            <div id="72d28165-8b31-4a4d-86ca-becd18ae2f33" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("72d28165-8b31-4a4d-86ca-becd18ae2f33")) {                    Plotly.newPlot(                        "72d28165-8b31-4a4d-86ca-becd18ae2f33",                        [{"alignmentgroup": "True", "hovertemplate": "salary=%{x}<br>percentage (%)=%{text}<extra></extra>", "legendgroup": "", "marker": {"color": "green"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "text": [60.0, 11.8, 5.9, 3.5, 1.2, 3.5, 1.2, 4.7, 1.2, 1.2, 1.2, 1.2, 1.2, 1.2, 1.2], "textposition": "outside", "texttemplate": "%{text:.2s}", "type": "bar", "x": ["$0-999", "1,000-1,999", "2,000-2,999", "3,000-3,999", "4,000-4,999", "5,000-7,499", "7,500-9,999", "10,000-14,999", "15,000-19,999", "25,000-29,999", "30,000-39,999", "70,000-79,999", "80,000-89,999", "90,000-99,999", "200,000-249,999"], "xaxis": "x", "y": [60.0, 11.8, 5.9, 3.5, 1.2, 3.5, 1.2, 4.7, 1.2, 1.2, 1.2, 1.2, 1.2, 1.2, 1.2], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"tracegroupgap": 0}, "plot_bgcolor": "white", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333 ...

# %% [markdown]
# # Annual salary of Nigerian Kagglers that are Data Software Engineers

# %%
nigeria_software_engineer = nigeria[nigeria["Q5"]=="Software Engineer"]

nigeria_software_engineer = nigeria_software_engineer["Q25"].value_counts(normalize=True) 
nigeria_software_engineer = nigeria_software_engineer.mul(100)
nigeria_software_engineer = nigeria_software_engineer.round(decimals=1)
nigeria_software_engineer = pd.DataFrame(data=nigeria_software_engineer)
nigeria_software_engineer.reset_index(inplace=True)
nigeria_software_engineer.columns = ["salary","percentage (%)"] 

salary_order = ["$0-999", "1,000-1,999", "2,000-2,999", "3,000-3,999", "4,000-4,999", "5,000-7,499",
               "7,500-9,999", "10,000-14,999", "15,000-19,999", "20,000-24,999", "25,000-29,999",
                "30,000-39,999", "40,000-49,999", "50,000-59,999", "60,000-69,999", "70,000-79,999",
               "80,000-89,999", "90,000-99,999", "100,000-124,999", "150,000-199,999", "200,000-249,999",
                ">$1,000,000"]

nigeria_software_engineer["salary"] = pd.Categorical(nigeria_software_engineer["salary"], categories=salary_order)
nigeria_software_engineer.sort_values(by="salary", inplace=True)

fig = px.bar(nigeria_software_engineer, x="salary", y="percentage (%)", text='percentage (%)', 
             title="Annual salary of Nigerian Kagglers that are Software Engineers")
fig.update_traces(texttemplate='%{text:.2s}', textposition='outside', marker_color=colors_ng, ) 
fig.update_layout(uniformtext_minsize=8, uniformtext_mode='hide', plot_bgcolor = "white")
fig.show()
# Out:
# <div>                            <div id="9b3b4149-ca8c-4345-875b-dd8c562598dc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9b3b4149-ca8c-4345-875b-dd8c562598dc")) {                    Plotly.newPlot(                        "9b3b4149-ca8c-4345-875b-dd8c562598dc",                        [{"alignmentgroup": "True", "hovertemplate": "salary=%{x}<br>percentage (%)=%{text}<extra></extra>", "legendgroup": "", "marker": {"color": "green"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "text": [34.2, 15.8, 21.1, 7.9, 5.3, 2.6, 2.6, 2.6, 5.3, 2.6], "textposition": "outside", "texttemplate": "%{text:.2s}", "type": "bar", "x": ["$0-999", "1,000-1,999", "2,000-2,999", "3,000-3,999", "4,000-4,999", "7,500-9,999", "10,000-14,999", "40,000-49,999", "60,000-69,999", ">$1,000,000"], "xaxis": "x", "y": [34.2, 15.8, 21.1, 7.9, 5.3, 2.6, 2.6, 2.6, 5.3, 2.6], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"tracegroupgap": 0}, "plot_bgcolor": "white", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778 ...

# %% [markdown]
# In general, the salary distribution for Data Analysts, Data Scientists and Software Engineers (Nigerian Kagglers) are similar and mainly earn less than $3,000 per year.
#
# A minor point is that there are more Software Engineers from the Nigerian Kaggle community earn more (66 percent) than 1000 USD per year compared to those that earn less (34 percent) than 1,000 USD per year.

# %%
len(nigeria_data_analyst), len(nigeria_data_scientist), len(nigeria_software_engineer)
# Out:
# (11, 15, 10)

# %%
#Almost half of Nigerian Kagglers (45%) earn less than $1,000 per year.

#About 60% of Nigerians earn less than $2,000 per year.

# %%
salary_rotw = rest_of_the_world["Q25"].value_counts(normalize=True) 
salary_rotw = salary_rotw.mul(100)
salary_rotw = salary_rotw.round(decimals=1)
salary_rotw = pd.DataFrame(data=salary_rotw)
salary_rotw.reset_index(inplace=True)
salary_rotw.columns = ["salary","percentage (%)"] 

salary_order = ["$0-999", "1,000-1,999", "2,000-2,999", "3,000-3,999", "4,000-4,999", "5,000-7,499",
               "7,500-9,999", "10,000-14,999", "15,000-19,999", "20,000-24,999", "25,000-29,999",
                "30,000-39,999", "40,000-49,999", "50,000-59,999", "60,000-69,999", "70,000-79,999",
                "80,000-89,999", "90,000-99,999", "100,000-124,999", "150,000-199,999", "200,000-249,999",
                ">$1,000,000"]

salary_rotw["salary"] = pd.Categorical(salary_rotw["salary"], categories=salary_order)
salary_rotw.sort_values(by="salary", inplace=True)


fig = px.bar(salary_rotw, x="salary", y="percentage (%)", text='percentage (%)', 
             title="Annual salary for the rest of the world")
fig.update_traces(texttemplate='%{text:.2s}', textposition='outside', marker_color=colors_rotw, ) 
fig.update_layout(uniformtext_minsize=8, uniformtext_mode='hide', plot_bgcolor = "white")
fig.show()
# Out:
# <div>                            <div id="aa8d05b2-0db0-40f4-921d-a5b01d6eebe8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aa8d05b2-0db0-40f4-921d-a5b01d6eebe8")) {                    Plotly.newPlot(                        "aa8d05b2-0db0-40f4-921d-a5b01d6eebe8",                        [{"alignmentgroup": "True", "hovertemplate": "salary=%{x}<br>percentage (%)=%{text}<extra></extra>", "legendgroup": "", "marker": {"color": "gold"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "text": [21.2, 6.1, 3.6, 2.4, 2.9, 4.5, 3.6, 6.2, 3.8, 3.9, 3.1, 4.9, 4.6, 4.7, 3.7, 3.1, 2.6, 2.3, 4.8, 2.6, 1.2, 0.4, 2.5, 0.6, 0.5, 0.2], "textposition": "outside", "texttemplate": "%{text:.2s}", "type": "bar", "x": ["$0-999", "1,000-1,999", "2,000-2,999", "3,000-3,999", "4,000-4,999", "5,000-7,499", "7,500-9,999", "10,000-14,999", "15,000-19,999", "20,000-24,999", "25,000-29,999", "30,000-39,999", "40,000-49,999", "50,000-59,999", "60,000-69,999", "70,000-79,999", "80,000-89,999", "90,000-99,999", "100,000-124,999", "150,000-199,999", "200,000-249,999", ">$1,000,000", null, null, null, null], "xaxis": "x", "y": [21.2, 6.1, 3.6, 2.4, 2.9, 4.5, 3.6, 6.2, 3.8, 3.9, 3.1, 4.9, 4.6, 4.7, 3.7, 3.1, 2.6, 2.3, 4.8, 2.6, 1.2, 0.4, 2.5, 0.6, 0.5, 0.2], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"tracegroupgap": 0}, "plot_bgcolor": "white", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888 ...

# %%
#On the other hand, only about 20% of people from other nationalities earn under $1,000.

# %% [markdown]
# # Programming

# %% [markdown]
# # How long have Nigerian Kagglers been programming?

# %%
prog_years_ng = nigeria["Q6"].value_counts(normalize=True)
prog_years_ng = prog_years_ng.mul(100)
prog_years_ng = prog_years_ng.round(decimals=1)
prog_years_ng = pd.DataFrame(data=prog_years_ng)
prog_years_ng.reset_index(inplace=True)
prog_years_ng.columns = ["years", "percentage (%)"]


prog_years_order = ["I have never written code", "< 1 years", "1-3 years", "3-5 years", "5-10 years",
                   "10-20 years", "20+ years"]


prog_years_ng["years"] = pd.Categorical(prog_years_ng["years"], categories=prog_years_order)
prog_years_ng.sort_values(by="years", inplace=True)


fig = px.bar(prog_years_ng, x="years", y="percentage (%)", text='percentage (%)', 
             title="Years of programming for Nigerian Kagglers")
fig.update_traces(texttemplate='%{text:.2s}', textposition='auto', marker_color=colors_ng) 
fig.update_layout(uniformtext_minsize=8, uniformtext_mode='hide', plot_bgcolor = "white")
fig.update_xaxes(tickangle=45)
fig.show()
# Out:
# <div>                            <div id="7ef5a58a-3be9-4e4c-99bb-b4ef152368db" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7ef5a58a-3be9-4e4c-99bb-b4ef152368db")) {                    Plotly.newPlot(                        "7ef5a58a-3be9-4e4c-99bb-b4ef152368db",                        [{"alignmentgroup": "True", "hovertemplate": "years=%{x}<br>percentage (%)=%{text}<extra></extra>", "legendgroup": "", "marker": {"color": "green"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "text": [7.3, 34.3, 38.3, 11.4, 6.6, 1.9, 0.3], "textposition": "auto", "texttemplate": "%{text:.2s}", "type": "bar", "x": ["I have never written code", "< 1 years", "1-3 years", "3-5 years", "5-10 years", "10-20 years", "20+ years"], "xaxis": "x", "y": [7.3, 34.3, 38.3, 11.4, 6.6, 1.9, 0.3], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"tracegroupgap": 0}, "plot_bgcolor": "white", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": " ...

# %%
#Most Nigerian Kagglers (72%) have less than 3 years of programming experience.

#7% of Nigerian Kagglers have never written code.

#Only about 9% of Nigerian Kagglers have over 5 years of programming experience.

# %%
prog_years_rotw = rest_of_the_world["Q6"].value_counts(normalize=True)
prog_years_rotw = prog_years_rotw.mul(100)
prog_years_rotw = prog_years_rotw.round(decimals=1)
prog_years_rotw = pd.DataFrame(data=prog_years_rotw)
prog_years_rotw.reset_index(inplace=True)
prog_years_rotw.columns = ["years", "percentage (%)"]

prog_years_order = ["I have never written code", "< 1 years", "1-3 years", "3-5 years", "5-10 years",
                   "10-20 years", "20+ years"]

prog_years_rotw["years"] = pd.Categorical(prog_years_rotw["years"], categories=prog_years_order)
prog_years_rotw.sort_values(by="years", inplace=True)



fig = px.bar(prog_years_rotw, x="years", y="percentage (%)", text='percentage (%)', 
             title="Years of programming for the rest of the world")
fig.update_traces(texttemplate='%{text:.2s}', textposition='auto', marker_color=colors_rotw, ) 
fig.update_layout(uniformtext_minsize=8, uniformtext_mode='hide', plot_bgcolor = "white")
fig.update_xaxes(tickangle=45)

fig.show()
# Out:
# <div>                            <div id="dea938d4-dfbb-455d-8477-0de73b06f982" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dea938d4-dfbb-455d-8477-0de73b06f982")) {                    Plotly.newPlot(                        "dea938d4-dfbb-455d-8477-0de73b06f982",                        [{"alignmentgroup": "True", "hovertemplate": "years=%{x}<br>percentage (%)=%{text}<extra></extra>", "legendgroup": "", "marker": {"color": "gold"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "text": [3.9, 22.3, 30.1, 15.8, 12.1, 8.5, 7.4], "textposition": "auto", "texttemplate": "%{text:.2s}", "type": "bar", "x": ["I have never written code", "< 1 years", "1-3 years", "3-5 years", "5-10 years", "10-20 years", "20+ years"], "xaxis": "x", "y": [3.9, 22.3, 30.1, 15.8, 12.1, 8.5, 7.4], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"tracegroupgap": 0}, "plot_bgcolor": "white", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type":  ...

# %% [markdown]
# # What programming languages do Nigerian Kagglers use?

# %%
prog_lang_ng = pd.DataFrame(nigeria.loc[:,list(nigeria.columns[7:20])].count(), columns=["count"])
prog_lang_ng["programming language"] = ['Python', 'R', 'SQL', 'C', 'C++', 'Java', 
                'Javascript', 'Julia', 'Swift','Bash', 'MATLAB', 'None', 'Other']
prog_lang_ng.sort_values(by = "count", inplace = True, ascending = False)

prog_lang_ng["percentage (%)"] = (prog_lang_ng["count"]/
                              prog_lang_ng["count"].sum()) * 100  

prog_lang_ng = prog_lang_ng.round(decimals=1)

fig = go.Figure(go.Treemap(
    labels = prog_lang_ng["programming language"],
    values = prog_lang_ng["percentage (%)"],
    parents = ['']*prog_lang_ng.shape[0], textinfo = "percent root+label+text", marker=dict(
        
        colorscale='greens',
        )
))

fig.update_layout(uniformtext_minsize=8, uniformtext_mode='hide', 
                  title= "Programming language used regularly by Nigerian Kagglers") 
fig.show()
# Out:
# <div>                            <div id="17ddb968-2229-4517-b118-a921595a0eae" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("17ddb968-2229-4517-b118-a921595a0eae")) {                    Plotly.newPlot(                        "17ddb968-2229-4517-b118-a921595a0eae",                        [{"labels": ["Python", "SQL", "Javascript", "R", "MATLAB", "Java", "C++", "Other", "C", "None", "Bash", "Swift", "Julia"], "marker": {"colorscale": [[0.0, "rgb(247,252,245)"], [0.125, "rgb(229,245,224)"], [0.25, "rgb(199,233,192)"], [0.375, "rgb(161,217,155)"], [0.5, "rgb(116,196,118)"], [0.625, "rgb(65,171,93)"], [0.75, "rgb(35,139,69)"], [0.875, "rgb(0,109,44)"], [1.0, "rgb(0,68,27)"]]}, "parents": ["", "", "", "", "", "", "", "", "", "", "", "", ""], "textinfo": "percent root+label+text", "type": "treemap", "values": [44.5, 17.9, 8.9, 8.3, 4.3, 4.2, 4.1, 3.3, 2.4, 1.1, 0.8, 0.2, 0.1]}],                        {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcon ...

# %%
#The top programming language for Nigerian Kagglers is Python, which is similar to the rest of the world. 

#Most Nigerian Kagglers use Python, SQL and Javascript

#Javascript ranks third compared to C++ which ranks third for the rest of the world.

# %%
prog_lang_rotw = pd.DataFrame(rest_of_the_world.loc[:,list(rest_of_the_world.columns[7:20])].count(), columns=["count"])
prog_lang_rotw["programming language"] = ['Python', 'R', 'SQL', 'C', 'C++', 'Java', 
                'Javascript', 'Julia', 'Swift','Bash', 'MATLAB', 'None', 'Other']
prog_lang_rotw.sort_values(by = "count", inplace = True, ascending = False)

prog_lang_rotw["percentage (%)"] = (prog_lang_rotw["count"]/
                              prog_lang_rotw["count"].sum()) * 100  

prog_lang_rotw = prog_lang_rotw.round(decimals=1)

fig = go.Figure(go.Treemap(
    labels = prog_lang_rotw["programming language"],
    values = prog_lang_rotw["percentage (%)"],
    parents = ['']*prog_lang_rotw.shape[0], textinfo = "percent root+label+text", marker=dict(
        
        colorscale='ylorbr',
        )
))

fig.update_layout(uniformtext_minsize=8, uniformtext_mode='hide', 
                  title= "Programming language used by the rest of the world") 
fig.show()
# Out:
# <div>                            <div id="53c017c0-cbc2-48b5-beae-2bc15d6d8eea" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("53c017c0-cbc2-48b5-beae-2bc15d6d8eea")) {                    Plotly.newPlot(                        "53c017c0-cbc2-48b5-beae-2bc15d6d8eea",                        [{"labels": ["Python", "SQL", "C++", "R", "Java", "C", "Javascript", "MATLAB", "Other", "Bash", "None", "Julia", "Swift"], "marker": {"colorscale": [[0.0, "rgb(255,255,229)"], [0.125, "rgb(255,247,188)"], [0.25, "rgb(254,227,145)"], [0.375, "rgb(254,196,79)"], [0.5, "rgb(254,153,41)"], [0.625, "rgb(236,112,20)"], [0.75, "rgb(204,76,2)"], [0.875, "rgb(153,52,4)"], [1.0, "rgb(102,37,6)"]]}, "parents": ["", "", "", "", "", "", "", "", "", "", "", "", ""], "textinfo": "percent root+label+text", "type": "treemap", "values": [33.0, 16.3, 8.5, 8.1, 7.3, 7.2, 6.5, 4.5, 3.9, 3.4, 0.5, 0.5, 0.4]}],                        {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcont ...

# %% [markdown]
# # Integrated development environment (IDE) used by Nigerian Kagglers

# %%
ide_ng = pd.DataFrame(nigeria.loc[:,list(nigeria.columns[21:34])].count(), columns=["count"])
ide_ng["IDE"] = ['Jupyter', 'Rstudio', 'Visual Studio', 'VScode', 
                     'PyCharm', 'Spyder', 'Notepad++', 'Sublime Text', 'Vim/Emacs','MATLAB', 
                     'Jupyter Notebook', 'None', 'Other']

ide_ng.sort_values(by = "count", inplace = True, ascending = False)

ide_ng["percentage (%)"] = (ide_ng["count"]/
                              ide_ng["count"].sum()) * 100  

ide_ng = ide_ng.round(decimals=1)

fig = px.bar(ide_ng, x="IDE", y="percentage (%)", text='percentage (%)', 
             title="IDES used by Nigerian Kagglers")
fig.update_traces(texttemplate='%{text:.2s}', textposition='outside', marker_color=colors_ng) 
fig.update_layout(uniformtext_minsize=8, uniformtext_mode='hide', plot_bgcolor = "white")
fig.show()
# Out:
# <div>                            <div id="3aac3439-6869-40a3-ae6f-4f6975db77a3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3aac3439-6869-40a3-ae6f-4f6975db77a3")) {                    Plotly.newPlot(                        "3aac3439-6869-40a3-ae6f-4f6975db77a3",                        [{"alignmentgroup": "True", "hovertemplate": "IDE=%{x}<br>percentage (%)=%{text}<extra></extra>", "legendgroup": "", "marker": {"color": "green"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "text": [29.6, 15.5, 11.5, 8.0, 6.4, 6.2, 6.1, 5.6, 4.5, 2.9, 2.1, 1.0, 0.6], "textposition": "outside", "texttemplate": "%{text:.2s}", "type": "bar", "x": ["Jupyter Notebook", "VScode", "PyCharm", "Jupyter", "Sublime Text", "Rstudio", "Visual Studio", "Notepad++", "Spyder", "MATLAB", "Other", "None", "Vim/Emacs"], "xaxis": "x", "y": [29.6, 15.5, 11.5, 8.0, 6.4, 6.2, 6.1, 5.6, 4.5, 2.9, 2.1, 1.0, 0.6], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"tracegroupgap": 0}, "plot_bgcolor": "white", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.66666666666666 ...

# %%
ide_rotw = pd.DataFrame(rest_of_the_world.loc[:,list(rest_of_the_world.columns[21:34])].count(), columns=["count"])
ide_rotw["IDE"] = ['Jupyter', 'Rstudio', 'Visual Studio', 'VScode', 
                     'PyCharm', 'Spyder', 'Notepad++', 'Sublime Text', 'Vim/Emacs','MATLAB', 
                     'Jupyter Notebook', 'None', 'Other']

ide_rotw.sort_values(by = "count", inplace = True, ascending = False)

ide_rotw["percentage (%)"] = (ide_rotw["count"]/
                              ide_rotw["count"].sum()) * 100  

ide_rotw = ide_rotw.round(decimals=1)

fig = px.bar(ide_rotw, x="IDE", y="percentage (%)", text='percentage (%)', 
             title="IDES used by the rest of the world")
fig.update_traces(texttemplate='%{text:.2s}', textposition='outside', marker_color=colors_rotw) 
fig.update_layout(uniformtext_minsize=8, uniformtext_mode='hide', plot_bgcolor = "white")
fig.show()
# Out:
# <div>                            <div id="4db98d70-837a-431d-83bf-1594da22c1f9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4db98d70-837a-431d-83bf-1594da22c1f9")) {                    Plotly.newPlot(                        "4db98d70-837a-431d-83bf-1594da22c1f9",                        [{"alignmentgroup": "True", "hovertemplate": "IDE=%{x}<br>percentage (%)=%{text}<extra></extra>", "legendgroup": "", "marker": {"color": "gold"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "text": [25.0, 15.6, 11.6, 8.5, 7.4, 6.4, 6.1, 5.9, 4.4, 3.4, 2.6, 2.3, 0.8], "textposition": "outside", "texttemplate": "%{text:.2s}", "type": "bar", "x": ["Jupyter Notebook", "VScode", "PyCharm", "Jupyter", "Rstudio", "Visual Studio", "Notepad++", "Spyder", "Sublime Text", "MATLAB", "Vim/Emacs", "Other", "None"], "xaxis": "x", "y": [25.0, 15.6, 11.6, 8.5, 7.4, 6.4, 6.1, 5.9, 4.4, 3.4, 2.6, 2.3, 0.8], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"tracegroupgap": 0}, "plot_bgcolor": "white", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.666666666666666 ...

# %%
#Jupyter Notebook is the most popular IDE among Nigerian Kagglers and the rest of the world.

#Similarly, the three most popular IDEs among Nigerian Kagglers and the rest of the world are 
#Jupyter Notebook, VScode and PyCharm.

# %% [markdown]
# # Machine Learning

# %% [markdown]
# # How long have Nigerian Kagglers been using Machine Learning methods?

# %%
ml_ng = nigeria["Q15"].value_counts(normalize=True)
ml_ng = ml_ng.mul(100)
ml_ng = ml_ng.round(decimals=1)
ml_ng = pd.DataFrame(data=ml_ng)
ml_ng.reset_index(inplace=True)
ml_ng.columns = ["years", "percentage (%)"]

ml_years_order = ["I do not use machine learning methods", "Under 1 year", "1-2 years", "2-3 years", "3-4 years",
                  "4-5 years","5-10 years", "10-20 years"]

ml_ng["years"] = pd.Categorical(ml_ng["years"], categories=ml_years_order)
ml_ng.sort_values(by="years", inplace=True)



fig = px.bar(ml_ng, x="years", y="percentage (%)", text='percentage (%)', 
             title="Years of using Machine Learning methods (Nigerian Kagglers)")
fig.update_traces(texttemplate='%{text:.2s}', textposition='auto', marker_color=colors_ng) 
fig.update_layout(uniformtext_minsize=8, uniformtext_mode='hide', plot_bgcolor = "white")
fig.update_xaxes(tickangle=45)

fig.show()
# Out:
# <div>                            <div id="94cd3cbe-8d31-4fb5-be40-d4592352f412" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("94cd3cbe-8d31-4fb5-be40-d4592352f412")) {                    Plotly.newPlot(                        "94cd3cbe-8d31-4fb5-be40-d4592352f412",                        [{"alignmentgroup": "True", "hovertemplate": "years=%{x}<br>percentage (%)=%{text}<extra></extra>", "legendgroup": "", "marker": {"color": "green"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "text": [19.8, 48.7, 21.0, 5.7, 1.9, 2.0, 0.8, 0.2], "textposition": "auto", "texttemplate": "%{text:.2s}", "type": "bar", "x": ["I do not use machine learning methods", "Under 1 year", "1-2 years", "2-3 years", "3-4 years", "4-5 years", "5-10 years", "10-20 years"], "xaxis": "x", "y": [19.8, 48.7, 21.0, 5.7, 1.9, 2.0, 0.8, 0.2], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"tracegroupgap": 0}, "plot_bgcolor": "white", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "# ...

# %%
#70% of Nigerian Kagglers have been applying Machine Learning methods for under two years

#20% of Nigerian Kagglers do use Machine Learning methods

# %%
ml_rotw = rest_of_the_world["Q15"].value_counts(normalize=True)
ml_rotw = ml_rotw.mul(100)
ml_rotw = ml_rotw.round(decimals=1)
ml_rotw = pd.DataFrame(data=ml_rotw)
ml_rotw.reset_index(inplace=True)
ml_rotw.columns = ["years", "percentage (%)"]

ml_years_order = ["I do not use machine learning methods", "Under 1 year", "1-2 years", "2-3 years", "3-4 years",
                  "4-5 years","5-10 years", "10-20 years"]

ml_rotw["years"] = pd.Categorical(ml_rotw["years"], categories=ml_years_order)
ml_rotw.sort_values(by="years", inplace=True)



fig = px.bar(ml_rotw, x="years", y="percentage (%)", text='percentage (%)', 
             title="Years of using Machine Learning methods (rest of the world)")
fig.update_traces(texttemplate='%{text:.2s}', textposition='auto', marker_color=colors_rotw) 
fig.update_layout(uniformtext_minsize=8, uniformtext_mode='hide', plot_bgcolor = "white")
fig.update_xaxes(tickangle=45)

fig.show()
# Out:
# <div>                            <div id="ba21ae9b-9935-4e20-ba59-16faa207c5d2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ba21ae9b-9935-4e20-ba59-16faa207c5d2")) {                    Plotly.newPlot(                        "ba21ae9b-9935-4e20-ba59-16faa207c5d2",                        [{"alignmentgroup": "True", "hovertemplate": "years=%{x}<br>percentage (%)=%{text}<extra></extra>", "legendgroup": "", "marker": {"color": "gold"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "text": [16.3, 38.3, 19.6, 9.8, 5.0, 4.0, 4.4, 1.6, 0.9], "textposition": "auto", "texttemplate": "%{text:.2s}", "type": "bar", "x": ["I do not use machine learning methods", "Under 1 year", "1-2 years", "2-3 years", "3-4 years", "4-5 years", "5-10 years", "10-20 years", null], "xaxis": "x", "y": [16.3, 38.3, 19.6, 9.8, 5.0, 4.0, 4.4, 1.6, 0.9], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"tracegroupgap": 0}, "plot_bgcolor": "white", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.88888 ...

# %% [markdown]
# # Machine Learning frameworks used by Nigerian Kagglers

# %%
ml_framework_ng = pd.DataFrame(nigeria.loc[:,list(nigeria.columns[72:90])].count(), columns=["count"])
ml_framework_ng["ml_framework"] = ['Scikit-learn', 'TensorFlow', 'Keras', 'PyTorch', 'Fast.ai',
       'MXNet', 'Xgboost', 'LightGBM', 'CatBoost', 'Prophet', "H2O 3", "Caret", "Tidymodels", "JAX",
                                "PyTorch Lightning", "Huggingface", 'None', 'Other']

ml_framework_ng.sort_values(by = "count", inplace = True, ascending = False)

ml_framework_ng["percentage (%)"] = (ml_framework_ng["count"]/
                              ml_framework_ng["count"].sum()) * 100  

ml_framework_ng = ml_framework_ng.round(decimals=1)

fig = px.bar(ml_framework_ng, x="ml_framework", y="percentage (%)", text='percentage (%)', 
             title="Machine Learning frameworks used regularly by Nigerian Kagglers")
fig.update_traces(texttemplate='%{text:.2s}', textposition='auto', marker_color=colors_ng) 
fig.update_layout(uniformtext_minsize=8, uniformtext_mode='hide', plot_bgcolor = "white")
fig.show()
# Out:
# <div>                            <div id="60b94ae9-ff4b-4b5b-83a9-579233c8ad9a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("60b94ae9-ff4b-4b5b-83a9-579233c8ad9a")) {                    Plotly.newPlot(                        "60b94ae9-ff4b-4b5b-83a9-579233c8ad9a",                        [{"alignmentgroup": "True", "hovertemplate": "ml_framework=%{x}<br>percentage (%)=%{text}<extra></extra>", "legendgroup": "", "marker": {"color": "green"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "text": [32.8, 15.7, 10.8, 10.2, 8.1, 6.7, 3.6, 3.3, 1.7, 1.7, 1.6, 1.1, 0.8, 0.6, 0.5, 0.4, 0.2, 0.1], "textposition": "auto", "texttemplate": "%{text:.2s}", "type": "bar", "x": ["Scikit-learn", "TensorFlow", "Keras", "Xgboost", "PyTorch", "None", "LightGBM", "CatBoost", "Tidymodels", "Caret", "Fast.ai", "PyTorch Lightning", "Other", "Huggingface", "MXNet", "Prophet", "JAX", "H2O 3"], "xaxis": "x", "y": [32.8, 15.7, 10.8, 10.2, 8.1, 6.7, 3.6, 3.3, 1.7, 1.7, 1.6, 1.1, 0.8, 0.6, 0.5, 0.4, 0.2, 0.1], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"tracegroupgap": 0}, "plot_bgcolor": "white", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.333333 ...

# %%
#Scikit-learn, TensorFlow and Keras are most popular Machine Learning frameworks used regularly by Nigerian Kagglers, this is also the same with the rest of the world.

# %%
ml_framework_rotw = pd.DataFrame(rest_of_the_world.loc[:,list(rest_of_the_world.columns[72:90])].count(), 
                                 columns=["count"])
ml_framework_rotw["ml_framework"] = ['Scikit-learn', 'TensorFlow', 'Keras', 'PyTorch', 'Fast.ai',
       'MXNet', 'Xgboost', 'LightGBM', 'CatBoost', 'Prophet', "H2O 3", "Caret", "Tidymodels", "JAX",
                                "PyTorch Lightning", "Huggingface", 'None', 'Other']

ml_framework_rotw.sort_values(by = "count", inplace = True, ascending = False)

ml_framework_rotw["percentage (%)"] = (ml_framework_rotw["count"]/
                              ml_framework_rotw["count"].sum()) * 100  

ml_framework_rotw = ml_framework_rotw.round(decimals=1)

fig = px.bar(ml_framework_rotw, x="ml_framework", y="percentage (%)", text='percentage (%)', 
             title="Machine Learning frameworks used regularly by the rest of the world")
fig.update_traces(texttemplate='%{text:.2s}', textposition='auto', marker_color=colors_rotw) 
fig.update_layout(uniformtext_minsize=8, uniformtext_mode='hide', plot_bgcolor = "white")
fig.show()
# Out:
# <div>                            <div id="745f6f9b-0b50-469a-8756-9a9881c910dc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("745f6f9b-0b50-469a-8756-9a9881c910dc")) {                    Plotly.newPlot(                        "745f6f9b-0b50-469a-8756-9a9881c910dc",                        [{"alignmentgroup": "True", "hovertemplate": "ml_framework=%{x}<br>percentage (%)=%{text}<extra></extra>", "legendgroup": "", "marker": {"color": "gold"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "text": [24.7, 16.7, 14.2, 10.9, 10.6, 4.7, 3.3, 2.7, 2.0, 1.9, 1.8, 1.5, 1.4, 1.2, 0.9, 0.8, 0.4, 0.3], "textposition": "auto", "texttemplate": "%{text:.2s}", "type": "bar", "x": ["Scikit-learn", "TensorFlow", "Keras", "PyTorch", "Xgboost", "LightGBM", "None", "CatBoost", "Huggingface", "PyTorch Lightning", "Caret", "Fast.ai", "Prophet", "Tidymodels", "H2O 3", "Other", "MXNet", "JAX"], "xaxis": "x", "y": [24.7, 16.7, 14.2, 10.9, 10.6, 4.7, 3.3, 2.7, 2.0, 1.9, 1.8, 1.5, 1.4, 1.2, 0.9, 0.8, 0.4, 0.3], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"tracegroupgap": 0}, "plot_bgcolor": "white", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.33333 ...

# %%
ml_algorithm_ng = pd.DataFrame(nigeria.loc[:,list(nigeria.columns[90:102])].count(), columns=["count"])
ml_algorithm_ng["ml_algorithm"] = ['Linear or Logistic Regression', 'Decision Trees or Random Forests', 
                                 'Gradient Boosting Machines (xgboost, lightgbm, etc)', 
                                 'Bayesian Approaches', 'Evolutionary Approaches',
                                 'Dense Neural Networks (MLPs, etc)', 
                                 'Convolutional Neural Networks', 'Generative Adversarial Networks', 
                                 'Recurrent Neural Networks', 'Transformer Networks (BERT, gpt-3, etc)', 
       'None', 'Other']

ml_algorithm_ng.sort_values(by = "count", inplace = True, ascending = False)

ml_algorithm_ng["percentage (%)"] = (ml_algorithm_ng["count"]/
                              ml_algorithm_ng["count"].sum()) * 100  

ml_algorithm_ng = ml_algorithm_ng.round(decimals=1)

fig = px.bar(ml_algorithm_ng, x="ml_algorithm", y="percentage (%)", text='percentage (%)', 
             title="Machine Learning algorithms used regularly by Nigerian Kagglers")
fig.update_traces(texttemplate='%{text:.2s}', textposition='auto', marker_color=colors_ng) 
fig.update_layout(uniformtext_minsize=8, uniformtext_mode='hide', plot_bgcolor = "white")
fig.show()
# Out:
# <div>                            <div id="58fc0d99-3b2b-445e-9e47-4a9518103e8d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("58fc0d99-3b2b-445e-9e47-4a9518103e8d")) {                    Plotly.newPlot(                        "58fc0d99-3b2b-445e-9e47-4a9518103e8d",                        [{"alignmentgroup": "True", "hovertemplate": "ml_algorithm=%{x}<br>percentage (%)=%{text}<extra></extra>", "legendgroup": "", "marker": {"color": "green"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "text": [31.4, 23.3, 10.5, 9.4, 6.8, 5.0, 4.3, 4.3, 2.1, 1.3, 0.7, 0.7], "textposition": "auto", "texttemplate": "%{text:.2s}", "type": "bar", "x": ["Linear or Logistic Regression", "Decision Trees or Random Forests", "Gradient Boosting Machines (xgboost, lightgbm, etc)", "Convolutional Neural Networks", "Bayesian Approaches", "Recurrent Neural Networks", "Dense Neural Networks (MLPs, etc)", "None", "Generative Adversarial Networks", "Transformer Networks (BERT, gpt-3, etc)", "Evolutionary Approaches", "Other"], "xaxis": "x", "y": [31.4, 23.3, 10.5, 9.4, 6.8, 5.0, 4.3, 4.3, 2.1, 1.3, 0.7, 0.7], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"tracegroupgap": 0}, "plot_bgcolor": "white", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscal ...

# %%
#Linear/Logistic Regression, Decision Trees/Random Forests and Gradient Boosting Machines(XGBoost, lightgbm, etc) are most popular Machine Learning algorithms used regularly by Nigerian Kagglers, this is also the same with the rest of the world.

# %%
ml_algorithm_rotw = pd.DataFrame(rest_of_the_world.loc[:,list(rest_of_the_world.columns[90:102])].count(), 
                                 columns=["count"])
ml_algorithm_rotw["ml_algorithm"] = ['Linear or Logistic Regression', 'Decision Trees or Random Forests', 
                                 'Gradient Boosting Machines (xgboost, lightgbm, etc)', 
                                 'Bayesian Approaches', 'Evolutionary Approaches',
                                 'Dense Neural Networks (MLPs, etc)', 
                                 'Convolutional Neural Networks', 'Generative Adversarial Networks', 
                                 'Recurrent Neural Networks', 'Transformer Networks (BERT, gpt-3, etc)', 
       'None', 'Other']

ml_algorithm_rotw.sort_values(by = "count", inplace = True, ascending = False)

ml_algorithm_rotw["percentage (%)"] = (ml_algorithm_rotw["count"]/
                              ml_algorithm_rotw["count"].sum()) * 100  

ml_algorithm_rotw = ml_algorithm_rotw.round(decimals=1)

fig = px.bar(ml_algorithm_rotw, x="ml_algorithm", y="percentage (%)", text='percentage (%)', 
             title="Machine Learning algorithms used regularly by the rest of the world")
fig.update_traces(texttemplate='%{text:.2s}', textposition='auto', marker_color=colors_rotw) 
fig.update_layout(uniformtext_minsize=8, uniformtext_mode='hide', plot_bgcolor = "white")
fig.show()
# Out:
# <div>                            <div id="7bad70ea-b6f4-43aa-a2cd-43a9e6c91be0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7bad70ea-b6f4-43aa-a2cd-43a9e6c91be0")) {                    Plotly.newPlot(                        "7bad70ea-b6f4-43aa-a2cd-43a9e6c91be0",                        [{"alignmentgroup": "True", "hovertemplate": "ml_algorithm=%{x}<br>percentage (%)=%{text}<extra></extra>", "legendgroup": "", "marker": {"color": "gold"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "text": [22.8, 19.6, 12.6, 12.3, 7.5, 7.3, 7.0, 3.8, 2.4, 2.2, 1.6, 0.8], "textposition": "auto", "texttemplate": "%{text:.2s}", "type": "bar", "x": ["Linear or Logistic Regression", "Decision Trees or Random Forests", "Gradient Boosting Machines (xgboost, lightgbm, etc)", "Convolutional Neural Networks", "Dense Neural Networks (MLPs, etc)", "Bayesian Approaches", "Recurrent Neural Networks", "Transformer Networks (BERT, gpt-3, etc)", "None", "Generative Adversarial Networks", "Evolutionary Approaches", "Other"], "xaxis": "x", "y": [22.8, 19.6, 12.6, 12.3, 7.5, 7.3, 7.0, 3.8, 2.4, 2.2, 1.6, 0.8], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"tracegroupgap": 0}, "plot_bgcolor": "white", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorsca ...

# %%
database_ng = pd.DataFrame(nigeria.loc[:,list(nigeria.columns[165:186])].count(), columns=["count"])
database_ng["database"] = ['MySQL', 'PostgreSQL', 'SQLite', 
                                 'Oracle Database', 'MongoDB',
                                 'Snowflake', 'IBM Db2', 'Microsoft SQL Server', 
                                 'Microsoft Azure SQL Database', 'Microsoft Azure Cosmos DB',
                         "Amazon Redshift", "Amazon Aurora", "Amazon RDS", "Amazon DynamoDB",
                         "Google Cloud BigQuery", "Google Cloud SQL", "Google Cloud Firestore",
                         "Google Cloud BigTable", "Google Cloud Spanner",
       'None', 'Other']

database_ng.sort_values(by = "count", inplace = True, ascending = False)

database_ng["percentage (%)"] = (database_ng["count"]/
                              database_ng["count"].sum()) * 100  

database_ng = database_ng.round(decimals=1)

fig = px.bar(database_ng, x="database", y="percentage (%)", text='percentage (%)', 
             title="Database used by Nigerian Kagglers")
fig.update_traces(texttemplate='%{text:.2s}', textposition='auto', marker_color=colors_ng) 
fig.update_layout(uniformtext_minsize=8, uniformtext_mode='hide', plot_bgcolor = "white")
fig.show()
# Out:
# <div>                            <div id="895080b1-cc62-44b3-9392-06b610b4290a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("895080b1-cc62-44b3-9392-06b610b4290a")) {                    Plotly.newPlot(                        "895080b1-cc62-44b3-9392-06b610b4290a",                        [{"alignmentgroup": "True", "hovertemplate": "database=%{x}<br>percentage (%)=%{text}<extra></extra>", "legendgroup": "", "marker": {"color": "green"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "text": [19.4, 10.4, 9.9, 8.3, 7.9, 5.7, 5.5, 4.4, 3.9, 3.9, 3.7, 3.6, 2.9, 2.6, 1.9, 1.6, 1.6, 1.3, 0.6, 0.6, 0.3], "textposition": "auto", "texttemplate": "%{text:.2s}", "type": "bar", "x": ["MySQL", "PostgreSQL", "None", "Microsoft SQL Server", "SQLite", "MongoDB", "Google Cloud BigQuery", "Google Cloud SQL", "Oracle Database", "Microsoft Azure Cosmos DB", "Google Cloud Firestore", "Microsoft Azure SQL Database", "IBM Db2", "Google Cloud BigTable", "Google Cloud Spanner", "Amazon RDS", "Amazon DynamoDB", "Amazon Redshift", "Amazon Aurora", "Snowflake", "Other"], "xaxis": "x", "y": [19.4, 10.4, 9.9, 8.3, 7.9, 5.7, 5.5, 4.4, 3.9, 3.9, 3.7, 3.6, 2.9, 2.6, 1.9, 1.6, 1.6, 1.3, 0.6, 0.6, 0.3], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"tracegroupgap": 0}, "plot_bgcolor": "white", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "hi ...

# %%
#The most common databases used by Nigerian Kagglers are:
#MySQL
#PostgreSQL
#Microsoft SQL Server

#This is the same as the rest of the world

# %%
database_rotw = pd.DataFrame(rest_of_the_world.loc[:,list(rest_of_the_world.columns[165:186])].count(), columns=["count"])
database_rotw["database"] = ['MySQL', 'PostgreSQL', 'SQLite', 
                                 'Oracle Database', 'MongoDB',
                                 'Snowflake', 'IBM Db2', 'Microsoft SQL Server', 
                                 'Microsoft Azure SQL Database', 'Microsoft Azure Cosmos DB',
                         "Amazon Redshift", "Amazon Aurora", "Amazon RDS", "Amazon DynamoDB",
                         "Google Cloud BigQuery", "Google Cloud SQL", "Google Cloud Firestore",
                         "Google Cloud BigTable", "Google Cloud Spanner",
       'None', 'Other']

database_rotw.sort_values(by = "count", inplace = True, ascending = False)

database_rotw["percentage (%)"] = (database_rotw["count"]/
                              database_rotw["count"].sum()) * 100  

database_rotw = database_rotw.round(decimals=1)

fig = px.bar(database_rotw, x="database", y="percentage (%)", text='percentage (%)', 
             title="Database used by the rest of the world")
fig.update_traces(texttemplate='%{text:.2s}', textposition='auto', marker_color=colors_rotw) 
fig.update_layout(uniformtext_minsize=8, uniformtext_mode='hide', plot_bgcolor = "white")
fig.show()
# Out:
# <div>                            <div id="86132780-f307-4f3c-b6c2-285b57b76978" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("86132780-f307-4f3c-b6c2-285b57b76978")) {                    Plotly.newPlot(                        "86132780-f307-4f3c-b6c2-285b57b76978",                        [{"alignmentgroup": "True", "hovertemplate": "database=%{x}<br>percentage (%)=%{text}<extra></extra>", "legendgroup": "", "marker": {"color": "gold"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "text": [16.9, 10.9, 10.7, 9.1, 7.9, 7.8, 5.3, 4.2, 3.7, 2.9, 2.8, 2.7, 2.4, 2.2, 1.7, 1.7, 1.6, 1.6, 1.6, 1.4, 0.9], "textposition": "auto", "texttemplate": "%{text:.2s}", "type": "bar", "x": ["MySQL", "None", "PostgreSQL", "Microsoft SQL Server", "MongoDB", "SQLite", "Oracle Database", "Google Cloud BigQuery", "Microsoft Azure SQL Database", "Amazon RDS", "Amazon Redshift", "Google Cloud SQL", "Snowflake", "Amazon DynamoDB", "Other", "Microsoft Azure Cosmos DB", "Google Cloud Firestore", "IBM Db2", "Google Cloud BigTable", "Amazon Aurora", "Google Cloud Spanner"], "xaxis": "x", "y": [16.9, 10.9, 10.7, 9.1, 7.9, 7.8, 5.3, 4.2, 3.7, 2.9, 2.8, 2.7, 2.4, 2.2, 1.7, 1.7, 1.6, 1.6, 1.6, 1.4, 0.9], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"tracegroupgap": 0}, "plot_bgcolor": "white", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "h ...

# %% [markdown]
# # Favourite media source on data science topics

# %%
media_source_ng = pd.DataFrame(nigeria.loc[:,list(nigeria.columns[256:268])].count(), columns=["count"])
media_source_ng["media_source"] = ['Twitter', 'Email newsletters', 'Reddit', 'Kaggle', 'Course Forums',
       'YouTube', 'Podcasts', 'Blogs', 'Journal Publications', 'Slack Communities',
       'None', 'Other']

media_source_ng.sort_values(by = "count", inplace = True, ascending = False)

media_source_ng["percentage (%)"] = (media_source_ng["count"]/
                              media_source_ng["count"].sum()) * 100  

media_source_ng = media_source_ng.round(decimals=1)

fig = go.Figure(go.Treemap(
    labels = media_source_ng["media_source"],
    values = media_source_ng["percentage (%)"] ,
    parents = ['']*media_source_ng.shape[0], textinfo = "percent root+label+text", marker=dict(
        
        colorscale='greens',
        )
))

fig.update_layout(uniformtext_minsize=8, uniformtext_mode='hide', 
                  title= "Favourite media source on data science topics for Nigerian Kagglers") 
fig.show()
# Out:
# <div>                            <div id="46001390-3ef8-4a00-a66b-0815b9bfeaca" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("46001390-3ef8-4a00-a66b-0815b9bfeaca")) {                    Plotly.newPlot(                        "46001390-3ef8-4a00-a66b-0815b9bfeaca",                        [{"labels": ["Kaggle", "YouTube", "Blogs", "Twitter", "Email newsletters", "Slack Communities", "Course Forums", "Journal Publications", "Reddit", "Podcasts", "None", "Other"], "marker": {"colorscale": [[0.0, "rgb(247,252,245)"], [0.125, "rgb(229,245,224)"], [0.25, "rgb(199,233,192)"], [0.375, "rgb(161,217,155)"], [0.5, "rgb(116,196,118)"], [0.625, "rgb(65,171,93)"], [0.75, "rgb(35,139,69)"], [0.875, "rgb(0,109,44)"], [1.0, "rgb(0,68,27)"]]}, "parents": ["", "", "", "", "", "", "", "", "", "", "", ""], "textinfo": "percent root+label+text", "type": "treemap", "values": [21.5, 18.1, 13.6, 10.5, 9.8, 7.7, 6.5, 4.7, 3.7, 2.2, 1.0, 0.7]}],                        {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca2 ...

# %%
#The top three favourite media sources on data science topics by Nigerian Kagglers are:
#Kaggle, YouTube and Blogs

# %%
media_source_rotw = pd.DataFrame(rest_of_the_world.loc[:,list(rest_of_the_world.columns[256:268])].count(), 
                                 columns=["count"])
media_source_rotw["media_source"] = ['Twitter', 'Email newsletters', 'Reddit', 'Kaggle', 'Course Forums',
       'YouTube', 'Podcasts', 'Blogs', 'Journal Publications', 'Slack Communities',
       'None', 'Other']

media_source_rotw.sort_values(by = "count", inplace = True, ascending = False)

media_source_rotw["percentage (%)"] = (media_source_rotw["count"]/
                              media_source_rotw["count"].sum()) * 100  

media_source_rotw = media_source_rotw.round(decimals=1)

fig = go.Figure(go.Treemap(
    labels = media_source_rotw["media_source"],
    values = media_source_rotw["percentage (%)"] ,
    parents = ['']*media_source_rotw.shape[0], textinfo = "percent root+label+text", marker=dict(
        
        colorscale='ylorbr',
        )
))

fig.update_layout(uniformtext_minsize=8, uniformtext_mode='hide', 
                  title= "Favourite media source on data science topics for the rest of the world") 
fig.show()
# Out:
# <div>                            <div id="ccf9e82e-36a1-4100-853f-bb1ea9008112" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ccf9e82e-36a1-4100-853f-bb1ea9008112")) {                    Plotly.newPlot(                        "ccf9e82e-36a1-4100-853f-bb1ea9008112",                        [{"labels": ["Kaggle", "YouTube", "Blogs", "Twitter", "Email newsletters", "Journal Publications", "Course Forums", "Reddit", "Podcasts", "Slack Communities", "None", "Other"], "marker": {"colorscale": [[0.0, "rgb(255,255,229)"], [0.125, "rgb(255,247,188)"], [0.25, "rgb(254,227,145)"], [0.375, "rgb(254,196,79)"], [0.5, "rgb(254,153,41)"], [0.625, "rgb(236,112,20)"], [0.75, "rgb(204,76,2)"], [0.875, "rgb(153,52,4)"], [1.0, "rgb(102,37,6)"]]}, "parents": ["", "", "", "", "", "", "", "", "", "", "", ""], "textinfo": "percent root+label+text", "type": "treemap", "values": [22.0, 20.1, 15.4, 7.1, 6.5, 6.5, 5.8, 5.7, 4.0, 3.7, 2.0, 1.1]}],                        {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26" ...

# %%
nigeria.head(3)
# Out:
#     Time from Start to Finish (seconds)     Q1   Q2       Q3  \
# 14                                  852  45-49  Man  Nigeria
# 15                                  838  22-24  Man  Nigeria
# 111                                 699  18-21  Man  Nigeria
#
#                     Q4                       Q5          Q6 Q7_Part_1  \
# 14     Master’s degree  Program/Project Manager  5-10 years    Python
# 15   Bachelor’s degree                    Other   < 1 years    Python
# 111  Bachelor’s degree                  Student   3-5 years    Python
#
#     Q7_Part_2 Q7_Part_3 Q7_Part_4 Q7_Part_5 Q7_Part_6 Q7_Part_7 Q7_Part_8  \
# 14        NaN       SQL       NaN       NaN       NaN       NaN       NaN
# 15        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 111       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#     Q7_Part_9 Q7_Part_10 Q7_Part_11 Q7_Part_12 Q7_OTHER      Q8  \
# 14        NaN        NaN        NaN        NaN      NaN  Python
# 15        NaN        NaN        NaN        NaN      NaN  Python
# 111       NaN        NaN        NaN        NaN      NaN  Python
#
#                                          Q9_Part_1 Q9_Part_2 Q9_Part_3  \
# 14                                             NaN       NaN       NaN
# 15                                             NaN       NaN       NaN
# 111  Jupyter (JupyterLab, Jupyter Notebooks, etc)        NaN       NaN
#
#                          Q9_Part_4  Q9_Part_5   Q9_Part_6 Q9_Part_7 Q9_Part_8  \
# 14                             NaN        NaN    Spyder         NaN       NaN
# 15    Visual Studio Code (VSCode)         NaN         NaN       NaN       NaN
# 111                            NaN   PyCharm          NaN       NaN       NaN
#
#     Q9_Part_9 Q9_Part_10         Q9_Part_11 Q9_Part_12 Q9_OTHER  \
# 14        NaN        NaN   Jupyter Notebook        NaN      NaN
# 15        NaN        NaN                NaN        NaN      NaN
# 111       NaN        NaN                NaN        NaN      NaN
#
#             Q10_Part_1 Q10_Part_2 Q10_Part_3 Q10_Part_4 Q10_Part_5 Q10_Part_6  \
# 14    Kaggle Notebooks        NaN        NaN        NaN        NaN        NaN
# 15                 NaN        NaN        NaN        NaN        NaN        NaN
# 111   Kaggle Notebooks        NaN        NaN        NaN        NaN        NaN
#
#     Q10_Part_7 Q10_Part_8 Q10_Part_9 Q10_Part_10 Q10_Part_11 Q10_Part_12  \
# 14         NaN        NaN        NaN         NaN         NaN         NaN
# 15         NaN        NaN        NaN         NaN         NaN         NaN
# 111        NaN        NaN        NaN         NaN         NaN         NaN
#
#     Q10_Part_13 Q10_Part_14 Q10_Part_15 Q10_Part_16 Q10_OTHER       Q11  \
# 14          NaN         NaN         NaN         NaN       NaN  A laptop
# 15          NaN         NaN         NaN        None       NaN  A laptop
# 111         NaN         NaN         NaN         NaN       NaN  A laptop
#
#         Q12_Part_1 Q12_Part_2 Q12_Part_3 Q12_Part_4 Q12_Part_5 Q12_OTHER  \
# 14             NaN        NaN        NaN        NaN       None       NaN
# 15    NVIDIA GPUs         NaN        NaN        NaN        NaN       NaN
# 111            NaN        NaN        NaN        NaN       None       NaN
#
#        Q13    Q14_Part_1 Q14_Part_2                 Q14_Part_3 Q14_Part_4  \
# 14   Never   Matplotlib    Seaborn                         NaN        NaN
# 15    Once           NaN        NaN   Plotly / Plotly Express         NaN
# 111  Never   Matplotlib         NaN                        NaN        NaN
#
#     Q14_Part_5 Q14_Part_6 Q14_Part_7 Q14_Part_8 Q14_Part_9 Q14_Part_10  \
# 14         NaN        NaN        NaN        NaN        NaN         NaN
# 15         NaN        NaN        NaN        NaN        NaN         NaN
# 111        NaN        NaN        NaN        NaN        NaN         NaN
#
#     Q14_Part_11 Q14_OTHER           Q15       Q16_Part_1     Q16_Part_2  \
# 14          NaN       NaN     1-2 years    Scikit-learn             NaN
# 15          NaN       NaN  Under 1 year              NaN    TensorFlow
# 111         NaN       NaN  Under 1 year              NaN            NaN
#
#     Q16_Part_3 Q16_Part_4 Q16_Part_5 Q16_Part_6 Q16_Part_7 Q16_Part_8  \
# 14         NaN        NaN        NaN        NaN   Xgboost         NaN
# 15         NaN        NaN        NaN        NaN        NaN        NaN
# 111        NaN        NaN        NaN        NaN        NaN        NaN
#
#     Q16_Part_9 Q16_Part_10 Q16_Part_11 Q16_Part_12 Q16_Part_13 Q16_Part_14  \
# 14         NaN         NaN         NaN         NaN         NaN         NaN
# 15         NaN         NaN         NaN         NaN         NaN         NaN
# 111        NaN         NaN         NaN         NaN         NaN         NaN
#
#     Q16_Part_15 Q16_Part_16 Q16_Part_17 Q16_OTHER  \
# 14          NaN         NaN         NaN       NaN
# 15          NaN         NaN         NaN       NaN
# 111         NaN         NaN        None       NaN
#
#                         Q17_Part_1                        Q17_Part_2  \
# 14   Linear or Logistic Regression  Decision Trees or Random Forests
# 15   Linear or Logistic Regression                               NaN
# 111                            NaN                               NaN
#
#     Q17_Part_3 Q17_Part_4 Q17_Part_5 Q17_Part_6 Q17_Part_7 Q17_Part_8  \
# 14         NaN        NaN        NaN        NaN        NaN        NaN
# 15         NaN        NaN        NaN        NaN        NaN        NaN
# 111        NaN        NaN        NaN        NaN        NaN        NaN
#
#     Q17_Part_9 Q17_Part_10 Q17_Part_11 Q17_OTHER Q18_Part_1 Q18_Part_2  \
# 14         NaN         NaN         NaN       NaN        NaN        NaN
# 15         NaN         NaN         NaN       NaN        NaN        NaN
# 111        NaN         NaN        None       NaN        NaN        NaN
#
#     Q18_Part_3 Q18_Part_4 Q18_Part_5 Q18_Part_6 Q18_OTHER Q19_Part_1  \
# 14         NaN        NaN        NaN        NaN       NaN        NaN
# 15         NaN        NaN        NaN        NaN       NaN        NaN
# 111        NaN        NaN        NaN        NaN       NaN        NaN
#
#     Q19_Part_2 Q19_Part_3 Q19_Part_4 Q19_Part_5 Q19_OTHER  \
# 14         NaN        NaN        NaN        NaN       NaN
# 15         NaN        NaN        NaN        NaN       NaN
# 111        NaN        NaN        NaN        NaN       NaN
#
#                          Q20                   Q21    Q22  \
# 14   Shipping/Transportation  1000-9,999 employees  10-14
# 15       Academics/Education        0-49 employees    1-2
# 111                      NaN                   NaN    NaN
#
#                                                    Q23  \
# 14   We are exploring ML methods (and may one day p...
# 15                       No (we do not use ML methods)
# 111                                                NaN
#
#                                             Q24_Part_1  \
# 14   Analyze and understand data to influence produ...
# 15   Analyze and understand data to influence produ...
# 111                                                NaN
#
#                                             Q24_Part_2 Q24_Part_3 Q24_Part_4  \
# 14   Build and/or run the data infrastructure that ...        NaN        NaN
# 15                                                 NaN        NaN        NaN
# 111                                                NaN        NaN        NaN
#
#     Q24_Part_5 Q24_Part_6 Q24_Part_7 Q24_OTHER          Q25        Q26  \
# 14         NaN        NaN        NaN       NaN  2,000-2,999  $100-$999
# 15         NaN        NaN        NaN       NaN       $0-999  $0 ($USD)
# 111        NaN        NaN        NaN       NaN          NaN        NaN
#
#     Q27_A_Part_1 Q27_A_Part_2 Q27_A_Part_3 Q27_A_Part_4    Q27_A_Part_5  \
# 14           NaN          NaN          NaN          NaN   Oracle Cloud
# 15           NaN          NaN          NaN          NaN             NaN
# 111          NaN          NaN          NaN          NaN             NaN
#
#     Q27_A_Part_6 Q27_A_Part_7 Q27_A_Part_8 Q27_A_Part_9 Q27_A_Part_10  \
# 14           NaN          NaN          NaN          NaN           NaN
# 15           NaN          NaN          NaN          NaN           NaN
# 111          NaN          NaN          NaN          NaN           NaN
#
#     Q27_A_Part_11 Q27_A_OTHER  Q28 Q29_A_Part_1 Q29_A_Part_2 Q29_A_Part_3  \
# 14            NaN         NaN  NaN          NaN          NaN          NaN
# 15            NaN         NaN  NaN          NaN          NaN          NaN
# 111           NaN         NaN  NaN          NaN          NaN          NaN
#
#     Q29_A_Part_4 Q29_A_OTHER Q30_A_Part_1 Q30_A_Part_2 Q30_A_Part_3  \
# 14           NaN         NaN          NaN          NaN          NaN
# 15           NaN         NaN          NaN          NaN          NaN
# 111          NaN         NaN          NaN          NaN          NaN
#
#     Q30_A_Part_4 Q30_A_Part_5 Q30_A_Part_6 Q30_A_Part_7 Q30_A_OTHER  \
# 14           NaN          NaN          NaN          NaN         NaN
# 15           NaN          NaN          NaN          NaN         NaN
# 111          NaN          NaN          NaN          NaN         NaN
#
#     Q31_A_Part_1 Q31_A_Part_2 Q31_A_Part_3 Q31_A_Part_4 Q31_A_Part_5  \
# 14           NaN          NaN          NaN          NaN          NaN
# 15           NaN          NaN          NaN          NaN          NaN
# 111          NaN          NaN          NaN          NaN          NaN
#
#     Q31_A_Part_6 Q31_A_Part_7 Q31_A_Part_8 Q31_A_Part_9 Q31_A_OTHER  \
# 14           NaN          NaN          NaN    No / None         NaN
# 15           NaN          NaN          NaN          NaN         NaN
# 111          NaN          NaN          NaN          NaN         NaN
#
#     Q32_A_Part_1 Q32_A_Part_2 Q32_A_Part_3      Q32_A_Part_4 Q32_A_Part_5  \
# 14           NaN          NaN          NaN  Oracle Database           NaN
# 15           NaN          NaN          NaN               NaN          NaN
# 111          NaN          NaN          NaN               NaN          NaN
#
#     Q32_A_Part_6 Q32_A_Part_7 Q32_A_Part_8 Q32_A_Part_9 Q32_A_Part_10  \
# 14           NaN          NaN          NaN          NaN           NaN
# 15           NaN          NaN          NaN          NaN           NaN
# 111          NaN          NaN          NaN          NaN           NaN
#
#     Q32_A_Part_11 Q32_A_Part_12 Q32_A_Part_13 Q32_A_Part_14 Q32_A_Part_15  \
# 14            NaN           NaN           NaN           NaN           NaN
# 15            NaN           NaN           NaN           NaN           NaN
# 111           NaN           NaN           NaN           NaN           NaN
#
#     Q32_A_Part_16 Q32_A_Part_17 Q32_A_Part_18 Q32_A_Part_19 Q32_A_Part_20  \
# 14            NaN           NaN           NaN           NaN           NaN
# 15            NaN           NaN           NaN           NaN           NaN
# 111           NaN           NaN           NaN           NaN           NaN
#
#     Q32_A_OTHER  Q33 Q34_A_Part_1 Q34_A_Part_2 Q34_A_Part_3 Q34_A_Part_4  \
# 14          NaN  NaN          NaN          NaN          NaN          NaN
# 15          NaN  NaN          NaN          NaN          NaN          NaN
# 111         NaN  NaN          NaN          NaN          NaN          NaN
#
#     Q34_A_Part_5 Q34_A_Part_6 Q34_A_Part_7 Q34_A_Part_8 Q34_A_Part_9  \
# 14           NaN          NaN          NaN          NaN          NaN
# 15           NaN          NaN          NaN          NaN          NaN
# 111          NaN          NaN          NaN          NaN          NaN
#
#     Q34_A_Part_10 Q34_A_Part_11 Q34_A_Part_12 Q34_A_Part_13 Q34_A_Part_14  \
# 14            NaN           NaN           NaN           NaN           NaN
# 15            NaN           NaN           NaN           NaN           NaN
# 111           NaN           NaN           NaN           NaN           NaN
#
#     Q34_A_Part_15 Q34_A_Part_16 Q34_A_OTHER  Q35 Q36_A_Part_1 Q36_A_Part_2  \
# 14            NaN          None         NaN  NaN          NaN          NaN
# 15            NaN           NaN         NaN  NaN          NaN          NaN
# 111           NaN           NaN         NaN  NaN          NaN          NaN
#
#     Q36_A_Part_3 Q36_A_Part_4 Q36_A_Part_5 Q36_A_Part_6 Q36_A_Part_7  \
# 14           NaN          NaN          NaN          NaN    No / None
# 15           NaN          NaN          NaN          NaN          NaN
# 111          NaN          NaN          NaN          NaN          NaN
#
#     Q36_A_OTHER Q37_A_Part_1 Q37_A_Part_2 Q37_A_Part_3 Q37_A_Part_4  \
# 14          NaN          NaN          NaN          NaN          NaN
# 15          NaN          NaN          NaN          NaN          NaN
# 111         NaN          NaN          NaN          NaN          NaN
#
#     Q37_A_Part_5 Q37_A_Part_6 Q37_A_Part_7 Q37_A_OTHER Q38_A_Part_1  \
# 14           NaN          NaN          NaN         NaN          NaN
# 15           NaN          NaN          NaN         NaN          NaN
# 111          NaN          NaN          NaN         NaN          NaN
#
#     Q38_A_Part_2 Q38_A_Part_3 Q38_A_Part_4 Q38_A_Part_5 Q38_A_Part_6  \
# 14           NaN          NaN          NaN          NaN          NaN
# 15           NaN          NaN          NaN          NaN          NaN
# 111          NaN          NaN          NaN          NaN          NaN
#
#     Q38_A_Part_7 Q38_A_Part_8 Q38_A_Part_9 Q38_A_Part_10 Q38_A_Part_11  \
# 14           NaN          NaN          NaN           NaN     No / None
# 15           NaN          NaN          NaN           NaN           NaN
# 111          NaN          NaN          NaN           NaN           NaN
#
#     Q38_A_OTHER Q39_Part_1 Q39_Part_2 Q39_Part_3 Q39_Part_4 Q39_Part_5  \
# 14          NaN        NaN        NaN        NaN        NaN        NaN
# 15          NaN        NaN        NaN        NaN        NaN        NaN
# 111         NaN        NaN        NaN        NaN        NaN        NaN
#
#     Q39_Part_6 Q39_Part_7 Q39_Part_8 Q39_Part_9 Q39_OTHER Q40_Part_1  \
# 14     Kaggle         NaN        NaN        NaN       NaN   Coursera
# 15         NaN        NaN        NaN        NaN       NaN   Coursera
# 111        NaN        NaN        NaN        NaN       NaN        NaN
#
#     Q40_Part_2            Q40_Part_3 Q40_Part_4 Q40_Part_5 Q40_Part_6  \
# 14         edX  Kaggle Learn Courses   DataCamp        NaN        NaN
# 15         NaN                   NaN        NaN        NaN        NaN
# 111        NaN                   NaN        NaN        NaN        NaN
#
#     Q40_Part_7 Q40_Part_8 Q40_Part_9 Q40_Part_10 Q40_Part_11 Q40_OTHER  \
# 14       Udemy        NaN        NaN         NaN         NaN       NaN
# 15         NaN        NaN        NaN         NaN         NaN       NaN
# 111        NaN        NaN        NaN         NaN         NaN       NaN
#
#                                                    Q41 Q42_Part_1  \
# 14   Local development environments (RStudio, Jupyt...        NaN
# 15   Basic statistical software (Microsoft Excel, G...        NaN
# 111                                                NaN        NaN
#
#                                             Q42_Part_2 Q42_Part_3  \
# 14                                                 NaN        NaN
# 15   Email newsletters (Data Elixir, O'Reilly Data ...        NaN
# 111                                                NaN        NaN
#
#                           Q42_Part_4 Q42_Part_5  \
# 14   Kaggle (notebooks, forums, etc)        NaN
# 15                               NaN        NaN
# 111                              NaN        NaN
#
#                                             Q42_Part_6  \
# 14   YouTube (Kaggle YouTube, Cloud AI Adventures, ...
# 15                                                 NaN
# 111                                                NaN
#
#                                             Q42_Part_7  \
# 14                                                 NaN
# 15   Podcasts (Chai Time Data Science, O’Reilly Dat...
# 111                                                NaN
#
#                                             Q42_Part_8 Q42_Part_9 Q42_Part_10  \
# 14   Blogs (Towards Data Science, Analytics Vidhya,...        NaN         NaN
# 15   Blogs (Towards Data Science, Analytics Vidhya,...        NaN         NaN
# 111                                                NaN        NaN         NaN
#
#     Q42_Part_11 Q42_OTHER                 Q27_B_Part_1       Q27_B_Part_2  \
# 14          NaN       NaN                          NaN                NaN
# 15          NaN       NaN                          NaN   Microsoft Azure
# 111         NaN       NaN   Amazon Web Services (AWS)                 NaN
#
#                       Q27_B_Part_3 Q27_B_Part_4 Q27_B_Part_5 Q27_B_Part_6  \
# 14                             NaN          NaN          NaN          NaN
# 15                             NaN          NaN          NaN          NaN
# 111   Google Cloud Platform (GCP)           NaN          NaN          NaN
#
#     Q27_B_Part_7 Q27_B_Part_8 Q27_B_Part_9 Q27_B_Part_10 Q27_B_Part_11  \
# 14           NaN          NaN          NaN           NaN           NaN
# 15           NaN          NaN          NaN           NaN           NaN
# 111          NaN          NaN          NaN           NaN           NaN
#
#     Q27_B_OTHER Q29_B_Part_1                        Q29_B_Part_2  \
# 14          NaN          NaN                                 NaN
# 15          NaN          NaN   Microsoft Azure Virtual Machines
# 111         NaN          NaN                                 NaN
#
#                       Q29_B_Part_3 Q29_B_Part_4 Q29_B_OTHER Q30_B_Part_1  \
# 14                             NaN          NaN         NaN          NaN
# 15                             NaN          NaN         NaN          NaN
# 111   Google Cloud Compute Engine           NaN         NaN          NaN
#
#     Q30_B_Part_2 Q30_B_Part_3 Q30_B_Part_4 Q30_B_Part_5 Q30_B_Part_6  \
# 14           NaN          NaN          NaN          NaN          NaN
# 15           NaN          NaN          NaN          NaN          NaN
# 111          NaN          NaN          NaN          NaN          NaN
#
#     Q30_B_Part_7 Q30_B_OTHER Q31_B_Part_1                     Q31_B_Part_2  \
# 14           NaN         NaN          NaN                              NaN
# 15           NaN         NaN          NaN   Azure Machine Learning Studio
# 111          NaN         NaN          NaN                              NaN
#
#     Q31_B_Part_3 Q31_B_Part_4 Q31_B_Part_5 Q31_B_Part_6 Q31_B_Part_7  \
# 14           NaN          NaN          NaN          NaN          NaN
# 15           NaN          NaN   Databricks          NaN          NaN
# 111          NaN    DataRobot   Databricks          NaN          NaN
#
#     Q31_B_Part_8 Q31_B_Part_9 Q31_B_OTHER Q32_B_Part_1 Q32_B_Part_2  \
# 14           NaN          NaN         NaN          NaN          NaN
# 15           NaN          NaN         NaN       MySQL           NaN
# 111   Rapidminer          NaN         NaN       MySQL   PostgreSQL
#
#     Q32_B_Part_3 Q32_B_Part_4 Q32_B_Part_5 Q32_B_Part_6 Q32_B_Part_7  \
# 14           NaN          NaN          NaN          NaN          NaN
# 15           NaN          NaN          NaN          NaN          NaN
# 111          NaN          NaN          NaN          NaN          NaN
#
#               Q32_B_Part_8                   Q32_B_Part_9 Q32_B_Part_10  \
# 14                     NaN                            NaN           NaN
# 15   Microsoft SQL Server   Microsoft Azure SQL Database            NaN
# 111                    NaN                            NaN           NaN
#
#     Q32_B_Part_11 Q32_B_Part_12 Q32_B_Part_13 Q32_B_Part_14 Q32_B_Part_15  \
# 14            NaN           NaN           NaN           NaN           NaN
# 15            NaN           NaN           NaN           NaN           NaN
# 111           NaN           NaN           NaN           NaN           NaN
#
#     Q32_B_Part_16 Q32_B_Part_17 Q32_B_Part_18 Q32_B_Part_19 Q32_B_Part_20  \
# 14            NaN           NaN           NaN           NaN           NaN
# 15            NaN           NaN           NaN           NaN           NaN
# 111           NaN           NaN           NaN           NaN           NaN
#
#     Q32_B_OTHER        Q34_B_Part_1 Q34_B_Part_2        Q34_B_Part_3  \
# 14          NaN                 NaN          NaN                 NaN
# 15          NaN                 NaN          NaN  Google Data Studio
# 111         NaN  Microsoft Power BI          NaN  Google Data Studio
#
#     Q34_B_Part_4 Q34_B_Part_5 Q34_B_Part_6 Q34_B_Part_7 Q34_B_Part_8  \
# 14           NaN          NaN          NaN          NaN          NaN
# 15           NaN          NaN          NaN  Tableau CRM          NaN
# 111          NaN          NaN          NaN          NaN          NaN
#
#     Q34_B_Part_9 Q34_B_Part_10 Q34_B_Part_11 Q34_B_Part_12 Q34_B_Part_13  \
# 14           NaN           NaN           NaN           NaN           NaN
# 15           NaN           NaN           NaN           NaN           NaN
# 111          NaN           NaN           NaN           NaN           NaN
#
#                 Q34_B_Part_14 Q34_B_Part_15 Q34_B_Part_16 Q34_B_OTHER  \
# 14                        NaN           NaN           NaN         NaN
# 15   Microsoft Azure Synapse            NaN           NaN         NaN
# 111                       NaN           NaN           NaN         NaN
#
#     Q36_B_Part_1 Q36_B_Part_2  \
# 14           NaN          NaN
# 15           NaN          NaN
# 111          NaN          NaN
#
#                                           Q36_B_Part_3 Q36_B_Part_4  \
# 14                                                 NaN          NaN
# 15   Automated model selection (e.g. auto-sklearn, ...          NaN
# 111                                                NaN          NaN
#
#     Q36_B_Part_5 Q36_B_Part_6 Q36_B_Part_7 Q36_B_OTHER Q37_B_Part_1  \
# 14           NaN          NaN          NaN         NaN          NaN
# 15           NaN          NaN          NaN         NaN          NaN
# 111          NaN          NaN          NaN         NaN          NaN
#
#     Q37_B_Part_2 Q37_B_Part_3 Q37_B_Part_4 Q37_B_Part_5  \
# 14           NaN          NaN          NaN          NaN
# 15           NaN          NaN          NaN          NaN
# 111          NaN          NaN          NaN          NaN
#
#                             Q37_B_Part_6 Q37_B_Part_7 Q37_B_OTHER  \
# 14                                   NaN          NaN         NaN
# 15     Azure Automated Machine Learning           NaN         NaN
# 111                                  NaN          NaN         NaN
#
#     Q38_B_Part_1 Q38_B_Part_2 Q38_B_Part_3 Q38_B_Part_4   Q38_B_Part_5  \
# 14           NaN          NaN          NaN          NaN            NaN
# 15           NaN          NaN          NaN          NaN   TensorBoard
# 111          NaN          NaN          NaN          NaN            NaN
#
#     Q38_B_Part_6 Q38_B_Part_7 Q38_B_Part_8 Q38_B_Part_9 Q38_B_Part_10  \
# 14           NaN          NaN          NaN          NaN           NaN
# 15           NaN          NaN          NaN          NaN           NaN
# 111          NaN          NaN          NaN          NaN           NaN
#
#     Q38_B_Part_11 Q38_B_OTHER
# 14            NaN         NaN
# 15            NaN         NaN
# 111           NaN         NaN

# %%
nigeria_1 = pd.DataFrame(nigeria, columns=["Q5", "Q25"])
nigeria_1.head(3)
# Out:
#                           Q5          Q25
# 14   Program/Project Manager  2,000-2,999
# 15                     Other       $0-999
# 111                  Student          NaN

# %%
salary_ng
# Out:
#              salary  percentage (%)
# 0            $0-999            45.3
# 1       1,000-1,999            14.3
# 2       2,000-2,999             9.2
# 6       3,000-3,999             4.2
# 5       4,000-4,999             4.4
# 3       5,000-7,499             5.3
# 7       7,500-9,999             2.5
# 4     10,000-14,999             5.1
# 8     15,000-19,999             1.6
# 9     20,000-24,999             1.4
# 14    25,000-29,999             0.7
# 13    30,000-39,999             0.7
# 10    40,000-49,999             1.2
# 19    50,000-59,999             0.2
# 11    60,000-69,999             1.2
# 16    70,000-79,999             0.5
# 12    80,000-89,999             0.7
# 17    90,000-99,999             0.2
# 18  100,000-124,999             0.2
# 15  150,000-199,999             0.7
# 21  200,000-249,999             0.2
# 20      >$1,000,000             0.2

# %%
nigeria_2 = nigeria_1[~nigeria_1["Q25"].isin(["$0-999", "1,000-1,999", "2,000-2,999",
                                             "3,000-3,999", "4,000-4,999", "5,000-7,499",
                                             "7,500-9,999", "10,000-14,999",  "15,000-19,999",
                                                                                           ])]
nigeria_2.head(3)
# Out:
#                          Q5  Q25
# 111                 Student  NaN
# 196      Research Scientist  NaN
# 273  Currently not employed  NaN

# %%
len(nigeria_2)
# Out:
# 304

# %%
nigeria_2["Q25"].unique()
# Out:
# array([nan, '80,000-89,999', '60,000-69,999', '150,000-199,999',
#        '70,000-79,999', '20,000-24,999', '30,000-39,999', '40,000-49,999',
#        '25,000-29,999', '100,000-124,999', '>$1,000,000', '50,000-59,999',
#        '90,000-99,999', '200,000-249,999'], dtype=object)

# %%
nigeria_2.groupby("Q5").count()["Q25"].sort_values(ascending=False)
# Out:
# Q5
# Other                        6
# Data Scientist               6
# Data Analyst                 6
# Research Scientist           5
# Software Engineer            4
# Machine Learning Engineer    2
# Data Engineer                2
# Business Analyst             2
# Program/Project Manager      1
# Product Manager              1
# Student                      0
# Statistician                 0
# Currently not employed       0
# Name: Q25, dtype: int64
